# %% [markdown]
# # Sanity Checks for MultiplEYE and MeRID: HOW TO

# %% [markdown]
# Please specify if you run the sanity checks for MultiplEYE or MeRID data.

# %%
from prepare_language_folder import prepare_language_folder

version = "MeRID"  # or "MeRID"

# %%
if version == "MultiplEYE":
	from run_multipleye_sanity_checks import run_multipleye_sanity_checks as sanity_check_function
elif version == "MeRID":
	from run_merid_sanity_checks import run_merid_sanity_checks as sanity_check_function
else:
	raise ValueError("version must be either 'MultiplEYE' or 'MeRID'")

# %% [markdown]
# ## Preparation steps
# 1. Download the data folder from the online repository. Download the entire folder, e.g., `MultiplEYE_ZH_CH_Zurich_1_2025`.
# When you download it from SwitchDrive, it will automatically create a .tar file.
# 2. Add the folder to the `data/` folder in this repo.
# 3. Extract the .tar file in the `data/` folder.

# %% [markdown]
# TODO: add correct structure of the data folder for preprocessing

# %% [markdown]
# ## Specify arguments
# As the next steps, specify the arguments for the sanity check script.

# %%
data_name = "MultiplEYE_HR_HR_Zagreb_1_2025"  # Name of the data folder
sessions_to_check = [
]  # List of session numbers to check
include_pilots = True # whether to include pilot data in the check
generate_plots = True  # whether to generate plots in the check

# %% [markdown]
# Run the preparation function to prepare the language folder structure. It will:
# - unzip session folders if needed
# - move session folders from core_sessions folder to the top folder
# - check if there is a config file in the stimuli folder (if not, the stimulus folder was probably not uloaded correctly)
# - check if there are psychometric tests (if applicable)
# 	- if necessary, restructure the psychometric test folder

# %%
prepare_language_folder(data_collection_name=data_name)

# %% [markdown]
# ## Run the sanity check

# %%
sanity_check_function(
	data_collection_name=data_name,
	#sessions_to_check=sessions_to_check,
	include_pilots=include_pilots,
	create_plots=generate_plots,
)
# Out:
# Folder test_sessions does not match the regex pattern \d\d\d_HR_HR_1_ET\d. Not considered as session.
# Folder pilot_sessions does not match the regex pattern \d\d\d_HR_HR_1_ET\d. Not considered as session.
# Folder Nova mapa does not match the regex pattern \d\d\d_HR_HR_1_ET\d. Not considered as session.
# Converting EDF to ASC: 100%|██████████| 5/5 [00:00<00:00, 18444.61it/s]
# WARNING:root:Preprocessing gaze data for 001_HR_HR_1_ET1. This might take a while.
# ---------------------------------------------------------------------------
# DuplicateError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 sanity_check_function(
#       2 	data_collection_name=data_name,
#       3 	#sessions_to_check=sessions_to_check,
#       4 	include_pilots=include_pilots,
#       5 	create_plots=generate_plots,
#       6 )
#
# File ~/repos/multipleye-preprocessing/run_merid_sanity_checks.py:22, in run_merid_sanity_checks(data_collection_name, full_path, create_plots, include_pilots, sessions_to_check)
#      19         data_folder_path = Path(full_path) / data_collection_name
#      21 logging.basicConfig(level=logging.INFO, filename=data_folder_path / 'sanity_checks_logfile.log')
# ---> 22 merid = Merid.create_from_data_folder(str(data_folder_path), include_pilots=include_pilots)
#      24 merid.create_sanity_check_report(
#      25     plotting=create_plots,
#      26     sessions=sessions_to_check,
#      27     overwrite=True,
#      28 )
#      30 if len(merid.excluded_sessions) >= 1:
#
# File ~/repos/multipleye-preprocessing/preprocessing/data_collection/multipleye_data_collection.py:185, in MultipleyeDataCollection.create_from_data_folder(cls, data_dir, additional_folder, include_pilots)
#     180 et_data_path = data_dir / 'eye-tracking-sessions' / \
#     181     additional_folder if additional_folder else data_dir / 'eye-tracking-sessions'
#     182 ps_tests_path = data_dir / 'psychometric-tests-sessions' / \
#     183     additional_folder if additional_folder else data_dir / 'psychometric-tests'
# --> 185 return cls(
#     186     data_collection_name=data_folder_name,
#     187     stimulus_language=stimulus_language,
#     188     country=country,
#     189     year=int(year),
#     190     eye_tracker=eye_tracker,
#     191     session_folder_regex=session_folder_regex,
#     192     config_file=config_file,
#     193     stimulus_dir=stimulus_folder_path,
#     194     lab_number=int(lab_number),
#     195     city=city,
#     196     data_root=et_data_path,
#     197     lab_configuration=lab_configuration_data,
#     198     include_pilots=include_pilots,
#     199     pilot_folder=et_data_path / 'pilot_sessions' if include_pilots else None,
#     200     psychometric_tests=psychometric_tests,
#     201     ps_tests_path=ps_tests_path,
#     202 )
#
# File ~/repos/multipleye-preprocessing/preprocessing/data_collection/multipleye_data_collection.py:101, in MultipleyeDataCollection.__init__(self, config_file, stimulus_dir, lab_number, city, data_root, lab_configuration, session_folder_regex, **kwargs)
#      97 stim_order_versions = pd.read_csv(stim_order_versions)
#      98 self.stim_order_versions = stim_order_versions[stim_order_versions['participant_id'].notnull(
#      99 )]
# --> 101 self.prepare_session_level_information()
#     102 self.parse_participant_data()
#     104 self.overview = self.create_dataset_overview()
#
# File ~/repos/multipleye-preprocessing/preprocessing/data_collection/multipleye_data_collection.py:352, in prepare_session_level_information(self)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File ~/repos/multipleye-preprocessing/preprocessing/data_collection/multipleye_data_collection.py:406, in create_gaze_frame(self, session, overwrite)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File ~/repos/multipleye-preprocessing/preprocessing/plotting/plot.py:104, in preprocess(gaze, sg_window_length, sg_degree)
#     102 def plot_gaze(gaze: pm.GazeDataFrame, stimulus: Stimulus, plots_dir: Path) -> None:
#     103     for page in stimulus.pages:
# --> 104         screen_gaze = gaze.frame.filter(
#     105             (pl.col("stimulus") == f"{stimulus.name}_{stimulus.id}")
#     106             & (pl.col("screen") == f"page_{page.number}")
#     107         ).select(
#     108             pl.col("pixel").list.get(0).alias("pixel_x"),
#     109             pl.col("pixel").list.get(1).alias("pixel_y"),
#     110         )
#     111         page_events = gaze.events.frame.filter(
#     112             (pl.col("stimulus") == f"{stimulus.name}_{stimulus.id}")
#     113             & (pl.col("screen") == f"page_{page.number}")
#    (...)
#     118             pl.col("location").list.get(1).alias("pixel_y"),
#     119         )
#     121         fig, ax = plt.subplots()
#
# File ~/repos/multipleye-preprocessing/.venv/lib/python3.11/site-packages/polars/dataframe/group_by.py:241, in GroupBy.agg(self, *aggs, **named_aggs)
#     135 """
#     136 Compute aggregations for each group of a group by operation.
#     137
#    (...)
#     233 └─────┴───────┴────────────────┘
#     234 """
#     235 from polars.lazyframe.opt_flags import QueryOptFlags
#     237 return (
#     238     self.df.lazy()
#     239     .group_by(*self.by, **self.named_by, maintain_order=self.maintain_order)
#     240     .agg(*aggs, **named_aggs)
# --> 241     .collect(optimizations=QueryOptFlags.none())
#     242 )
#
# File ~/repos/multipleye-preprocessing/.venv/lib/python3.11/site-packages/polars/_utils/deprecation.py:97, in deprecate_streaming_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#      93         kwargs["engine"] = "in-memory"
#      95     del kwargs["streaming"]
# ---> 97 return function(*args, **kwargs)
#
# File ~/repos/multipleye-preprocessing/.venv/lib/python3.11/site-packages/polars/lazyframe/opt_flags.py:330, in forward_old_opt_flags.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327         optflags = cb(optflags, kwargs.pop(key))  # type: ignore[no-untyped-call,unused-ignore]
#     329 kwargs["optimizations"] = optflags
# --> 330 return function(*args, **kwargs)
#
# File ~/repos/multipleye-preprocessing/.venv/lib/python3.11/site-packages/polars/lazyframe/frame.py:2332, in LazyFrame.collect(self, type_coercion, predicate_pushdown, projection_pushdown, simplify_expression, slice_pushdown, comm_subplan_elim, comm_subexpr_elim, cluster_with_columns, collapse_joins, no_optimization, engine, background, optimizations, **_kwargs)
#    2330 # Only for testing purposes
#    2331 callback = _kwargs.get("post_opt_callback", callback)
# -> 2332 return wrap_df(ldf.collect(engine, callback))
#
# DuplicateError: could not create a new DataFrame: column with name 'screen' has more than one occurrence
