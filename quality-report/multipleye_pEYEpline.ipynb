# %%
from multipleye_data_collection import MultipleyeDataCollection
from experiment_frame import ExperimentFrame
from pathlib import Path
import logging

# %% [markdown]
# ## Specify multipleye data collection folder

# %%
logging.basicConfig(level=logging.INFO)
data_collection_folder = 'MultiplEYE_HR_HR_Zagreb_1_2025'

# %%
this_repo = Path().resolve().parent
data_folder_path = this_repo / "data" / data_collection_folder 
print(data_folder_path)

multipleye = MultipleyeDataCollection.create_from_data_folder(str(data_folder_path), additional_folder= 'pilot_sessions')
# Out:
# C:\Users\saphi\PycharmProjects\multipleye-preprocessing\data\MultiplEYE_HR_HR_Zagreb_1_2025
# Folder Nova mapa does not match the regex pattern \d\d\d_HR_HR_1_ET\d. Not considered as session.
# Folder quality_reports does not match the regex pattern \d\d\d_HR_HR_1_ET\d. Not considered as session.
# Converting EDF to ASC: 100%|██████████| 6/6 [00:00<00:00, 1753.96it/s]
# ASC file already exists for 001_HR_HR_1_ET1.
# ASC file already exists for 001_HR_HR_1_ET2.
# ASC file already exists for 002_HR_HR_1_ET1.
# ASC file already exists for 002_HR_HR_1_ET2.
# ASC file already exists for 003_HR_HR_1_ET1.
# ASC file already exists for 003_HR_HR_1_ET2.

# %%
multipleye.generate_report("002_RU_RU_1_ET1")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 multipleye.generate_report("002_RU_RU_1_ET1")
#
# AttributeError: 'MultipleyeDataCollection' object has no attribute 'generate_report'

# %%
session_identifier = "005_RU_RU_1_ET1"

# %%
experiment = ExperimentFrame.load_from_multipleye_data_collection(multipleye, "005_RU_RU_1_ET1")

# %%
gaze =  multipleye.create_gaze_frame(session_identifier)
# Out:
# Creating gaze data:   0%|          | 0/1 [00:00<?, ?it/s]WARNING:root:Preprocessing gaze data for 005_RU_RU_1_ET1. This might take a while.
# Creating gaze data: 100%|██████████| 1/1 [04:15<00:00, 255.27s/it]

# %%
gaze = multipleye.get_gaze_frame(session_identifier)
# Out:
# C:\Users\saphi\PycharmProjects\multipleye-preprocessing\data\MultiplEYE_RU_RU_NewYork_1_2025\eye-tracking-sessions\quality_reports\005_RU_RU_1_ET1\005_RU_RU_1_ET1_gaze.pkl
# <class 'pathlib.WindowsPath'>
# <_io.BufferedReader name='C:\\Users\\saphi\\PycharmProjects\\multipleye-preprocessing\\data\\MultiplEYE_RU_RU_NewYork_1_2025\\eye-tracking-sessions\\quality_reports\\005_RU_RU_1_ET1\\005_RU_RU_1_ET1_gaze.pkl'>

# %%
gaze.experiment

# %%
multipleye.create_sanity_check_report(plotting= True)
# Out:
# performing sanity checks:   0%|          | 0/3 [00:00<?, ?it/s]
# Creating gaze data:   0%|          | 0/1 [00:00<?, ?it/s]WARNING:root:Preprocessing gaze data for 001_RU_RU_1_ET1. This might take a while.
#
# Creating gaze data: 100%|██████████| 1/1 [03:28<00:00, 208.43s/it]
# C:\Users\saphi\PycharmProjects\multipleye-preprocessing\data\MultiplEYE_RU_RU_NewYork_1_2025\eye-tracking-sessions\quality_reports\001_RU_RU_1_ET1\001_RU_RU_1_ET1_gaze.pkl
# <class 'pathlib.WindowsPath'>
# <_io.BufferedReader name='C:\\Users\\saphi\\PycharmProjects\\multipleye-preprocessing\\data\\MultiplEYE_RU_RU_NewYork_1_2025\\eye-tracking-sessions\\quality_reports\\001_RU_RU_1_ET1\\001_RU_RU_1_ET1_gaze.pkl'>
# INFO:root:Correct answers for PopSci_MultiplEYE: 0 out of 6 answers
# INFO:root:Correct answers for Ins_HumanRights: 1 out of 6 answers
# INFO:root:Correct answers for Ins_LearningMobility: 4 out of 6 answers
# INFO:root:Correct answers for Lit_Alchemist: 5 out of 6 answers
# INFO:root:Correct answers for Lit_MagicMountain: 3 out of 6 answers
# INFO:root:Correct answers for Lit_Solaris: 1 out of 6 answers
# INFO:root:Correct answers for Lit_BrokenApril: 4 out of 8 answers
# INFO:root:Correct answers for Arg_PISACowsMilk: 3 out of 8 answers
# INFO:root:Correct answers for Arg_PISARapaNui: 3 out of 6 answers
# INFO:root:Correct answers for PopSci_Caveman: 2 out of 6 answers
# INFO:root:Overall correct answers: 26 out of 64 answers 0.41
# Checking PopSci_MultiplEYE in Logfile
# Checking Ins_HumanRights in Logfile
# Checking Ins_LearningMobility in Logfile
# Checking Lit_Alchemist in Logfile
# Checking Lit_MagicMountain in Logfile
# Checking Lit_Solaris in Logfile
# Checking Lit_BrokenApril in Logfile
# Checking Arg_PISACowsMilk in Logfile
# Checking Arg_PISARapaNui in Logfile
# Checking PopSci_Caveman in Logfile
# 10, MSG	1113218.0 stimulus_order_version: 10
# INFO:root:1:  Arg_PISACowsMilk: 6.24 minutes
# INFO:root:2:  Lit_BrokenApril: 5.83 minutes
# INFO:root:3:  Lit_MagicMountain: 5.62 minutes
# INFO:root:4:  Arg_PISARapaNui: 5.6 minutes
# INFO:root:5: Ins_HumanRights: 4.59 minutes
# INFO:root:obligatory break: 0.64 minutes
# INFO:root:6:  PopSci_MultiplEYE: 6.05 minutes
# INFO:root:7:  Lit_Alchemist: 2.74 minutes
# INFO:root:8:  Ins_LearningMobility: 4.13 minutes
# INFO:root:9:  Lit_Solaris: 5.61 minutes
# INFO:root:10:  PopSci_Caveman: 3.14 minutes
# INFO:root:fixation_trigger:experimenter_calibration_triggered found 1 times
# INFO:root:fixation_trigger:experimenter_calibration_triggered found at 2109263.0
# INFO:root:optional_break found 8 times
# INFO:root:optional_break_duration: lasting 0.46 seconds found at 1625706.0
# INFO:root:optional_break_duration: lasting 5.74 seconds found at 1885501.0
# INFO:root:optional_break_duration: lasting 1.63 seconds found at 2291148.0
# INFO:root:optional_break_duration: lasting 5.29 seconds found at 2623858.0
# INFO:root:optional_break_duration: lasting 0.59 seconds found at 3365980.0
# INFO:root:optional_break_duration: lasting 0.85 seconds found at 3528092.0
# INFO:root:optional_break_duration: lasting 1.34 seconds found at 3762990.0
# INFO:root:optional_break_duration: lasting 1.18 seconds found at 4074152.0
# INFO:root:obligatory_break found 1 times
# INFO:root:obligatory_break_duration: lasting 1.43 seconds found at 2994743.0
# 10, MSG	1113218.0 stimulus_order_version: 10
# INFO:root:No calibration after validation 2/13 at 1687075.0 with validation score 0.45
# INFO:root:Calibration after validation at timestamp 2127035.0.   Next validation, 101.521 seconds later with score 0.31
# INFO:root:Calibration after validation at timestamp 2310670.0.   Next validation, 234.759 seconds later with score 0.26
# INFO:root:Calibration after validation at timestamp 2341544.0.   Next validation, 234.759 seconds later with score 0.26
# INFO:root:Calibration after validation at timestamp 2692287.0.   Next validation, 45.302 seconds later with score 0.41
# INFO:root:No calibration after validation 7/13 at 2713228.0 with validation score 0.41
# INFO:root:No calibration after validation 8/13 at 3027384.0 with validation score 0.37
# INFO:root:No calibration after validation 11/13 at 3802006.0 with validation score 0.49
# INFO:root:No calibration after validation 13/13 at 4330336.0 with validation score 0.40
# INFO:root: creating plots for 001_RU_RU_1_ET1.
# performing sanity checks:  33%|███▎      | 1/3 [04:15<08:31, 255.73s/it]
# Creating gaze data:   0%|          | 0/1 [00:00<?, ?it/s]WARNING:root:Preprocessing gaze data for 002_RU_RU_1_ET1. This might take a while.
#
# Creating gaze data: 100%|██████████| 1/1 [09:40<00:00, 580.30s/it]
# C:\Users\saphi\PycharmProjects\multipleye-preprocessing\data\MultiplEYE_RU_RU_NewYork_1_2025\eye-tracking-sessions\quality_reports\002_RU_RU_1_ET1\002_RU_RU_1_ET1_gaze.pkl
# <class 'pathlib.WindowsPath'>
# <_io.BufferedReader name='C:\\Users\\saphi\\PycharmProjects\\multipleye-preprocessing\\data\\MultiplEYE_RU_RU_NewYork_1_2025\\eye-tracking-sessions\\quality_reports\\002_RU_RU_1_ET1\\002_RU_RU_1_ET1_gaze.pkl'>
# INFO:root:Correct answers for PopSci_MultiplEYE: 4 out of 6 answers
# INFO:root:Correct answers for Ins_HumanRights: 2 out of 6 answers
# INFO:root:Correct answers for Ins_LearningMobility: 1 out of 6 answers
# INFO:root:Correct answers for Lit_Alchemist: 4 out of 6 answers
# INFO:root:Correct answers for Lit_MagicMountain: 4 out of 8 answers
# INFO:root:Correct answers for Lit_Solaris: 2 out of 6 answers
# INFO:root:Correct answers for Lit_BrokenApril: 1 out of 6 answers
# INFO:root:Correct answers for Arg_PISACowsMilk: 3 out of 6 answers
# INFO:root:Correct answers for Arg_PISARapaNui: 4 out of 8 answers
# INFO:root:Correct answers for PopSci_Caveman: 4 out of 6 answers
# INFO:root:Overall correct answers: 29 out of 64 answers 0.45
# Checking PopSci_MultiplEYE in Logfile
# Checking Ins_HumanRights in Logfile
# Checking Ins_LearningMobility in Logfile
# Checking Lit_Alchemist in Logfile
# Checking Lit_MagicMountain in Logfile
# Checking Lit_Solaris in Logfile
# Checking Lit_BrokenApril in Logfile
# Checking Arg_PISACowsMilk in Logfile
# Checking Arg_PISARapaNui in Logfile
# Checking PopSci_Caveman in Logfile
# WARNING:root:Missing question_MPRC_Arg_PISARapaNui_ru_11121 in asc file or in experiment frame
# WARNING:root:Missing question_MPRC_Arg_PISARapaNui_ru_11131 in asc file or in experiment frame
# WARNING:root:Missing question_MPRC_Arg_PISARapaNui_ru_11232 in asc file or in experiment frame
# 6, MSG	882687 stimulus_order_version: 6
# INFO:root:1:  Lit_MagicMountain: 6.62 minutes
# INFO:root:2:  Arg_PISARapaNui: 14.26 minutes
# INFO:root:3:  Lit_Solaris: 17.89 minutes
# INFO:root:4:  PopSci_Caveman: 10.21 minutes
# INFO:root:5: Arg_PISACowsMilk: 9.96 minutes
# INFO:root:obligatory break: 9.83 minutes
# INFO:root:6:  Lit_BrokenApril: 6.07 minutes
# INFO:root:7:  Ins_HumanRights: 5.05 minutes
# INFO:root:8:  PopSci_MultiplEYE: 17.7 minutes
# INFO:root:9:  Lit_Alchemist: 4.57 minutes
# INFO:root:10:  Ins_LearningMobility: 6.13 minutes
# INFO:root:fixation_trigger:experimenter_calibration_triggered found 6 times
# INFO:root:fixation_trigger:experimenter_calibration_triggered found at 1523867
# INFO:root:fixation_trigger:experimenter_calibration_triggered found at 1623088
# INFO:root:fixation_trigger:experimenter_calibration_triggered found at 2024426
# INFO:root:fixation_trigger:experimenter_calibration_triggered found at 2808499
# INFO:root:fixation_trigger:experimenter_calibration_triggered found at 2951100
# INFO:root:fixation_trigger:experimenter_calibration_triggered found at 5715498
# INFO:root:optional_break found 8 times
# INFO:root:optional_break_duration: lasting 7.02 seconds found at 1842642
# INFO:root:optional_break_duration: lasting 5.51 seconds found at 2676470
# INFO:root:optional_break_duration: lasting 9.60 seconds found at 3697767
# INFO:root:optional_break_duration: lasting 267.27 seconds found at 4388433
# INFO:root:optional_break_duration: lasting 8.83 seconds found at 5938761
# INFO:root:optional_break_duration: lasting 2.88 seconds found at 6244189
# INFO:root:optional_break_duration: lasting 489.66 seconds found at 7308205
# INFO:root:optional_break_duration: lasting 2.26 seconds found at 7576057
# INFO:root:obligatory_break found 1 times
# INFO:root:obligatory_break_duration: lasting 546.57 seconds found at 5564769
# 6, MSG	882687 stimulus_order_version: 6
# INFO:root:Calibration after validation at timestamp 1087844.   Next validation, 53.901 seconds later with score 0.41
# INFO:root:No calibration after validation 2/20 at 1102943.0 with validation score 0.41
# INFO:root:Calibration after validation at timestamp 1460523.   Next validation, 52.004 seconds later with score 0.35
# INFO:root:Calibration after validation at timestamp 1534491.   Next validation, 52.004 seconds later with score 0.35
# INFO:root:Calibration after validation at timestamp 1534491.   Next validation, 79.37 seconds later with score 0.45
# INFO:root:Calibration after validation at timestamp 1655956.   Next validation, 79.37 seconds later with score 0.45
# INFO:root:Calibration after validation at timestamp 1655956.   Next validation, 121.822 seconds later with score 0.29
# INFO:root:No calibration after validation 7/20 at 1873553.0 with validation score 0.35
# INFO:root:No calibration after validation 8/20 at 2464246.0 with validation score 0.40
# INFO:root:Calibration after validation at timestamp 2825493.   Next validation, 155.996 seconds later with score 0.25
# INFO:root:Calibration after validation at timestamp 2858628.   Next validation, 155.996 seconds later with score 0.25
# INFO:root:No calibration after validation 11/20 at 3362680.0 with validation score 0.34
# INFO:root:No calibration after validation 13/20 at 4415804.0 with validation score 0.33
# INFO:root:No calibration after validation 15/20 at 5742900.0 with validation score 0.38
# INFO:root:No calibration after validation 16/20 at 5967302.0 with validation score 0.34
# INFO:root:No calibration after validation 20/20 at 7976730.0 with validation score 0.33
# INFO:root: creating plots for 002_RU_RU_1_ET1.
# performing sanity checks:  67%|██████▋   | 2/3 [14:54<08:00, 480.76s/it]
# C:\Users\saphi\PycharmProjects\multipleye-preprocessing\data\MultiplEYE_RU_RU_NewYork_1_2025\eye-tracking-sessions\quality_reports\005_RU_RU_1_ET1\005_RU_RU_1_ET1_gaze.pkl
# <class 'pathlib.WindowsPath'>
# <_io.BufferedReader name='C:\\Users\\saphi\\PycharmProjects\\multipleye-preprocessing\\data\\MultiplEYE_RU_RU_NewYork_1_2025\\eye-tracking-sessions\\quality_reports\\005_RU_RU_1_ET1\\005_RU_RU_1_ET1_gaze.pkl'>
# INFO:root:Correct answers for PopSci_MultiplEYE: 5 out of 6 answers
# INFO:root:Correct answers for Ins_HumanRights: 4 out of 6 answers
# INFO:root:Correct answers for Ins_LearningMobility: 3 out of 6 answers
# INFO:root:Correct answers for Lit_Alchemist: 5 out of 6 answers
# INFO:root:Correct answers for Lit_MagicMountain: 4 out of 6 answers
# INFO:root:Correct answers for Lit_Solaris: 5 out of 6 answers
# INFO:root:Correct answers for Lit_BrokenApril: 4 out of 8 answers
# INFO:root:Correct answers for Arg_PISACowsMilk: 4 out of 8 answers
# INFO:root:Correct answers for Arg_PISARapaNui: 5 out of 6 answers
# INFO:root:Correct answers for PopSci_Caveman: 6 out of 6 answers
# INFO:root:Overall correct answers: 45 out of 64 answers 0.70
# Checking PopSci_MultiplEYE in Logfile
# Checking Ins_HumanRights in Logfile
# Checking Ins_LearningMobility in Logfile
# Checking Lit_Alchemist in Logfile
# Checking Lit_MagicMountain in Logfile
# Checking Lit_Solaris in Logfile
# Checking Lit_BrokenApril in Logfile
# Checking Arg_PISACowsMilk in Logfile
# Checking Arg_PISARapaNui in Logfile
# Checking PopSci_Caveman in Logfile
# 10, MSG	176158.0 stimulus_order_version: 10
# INFO:root:1:  Arg_PISACowsMilk: 9.97 minutes
# INFO:root:2:  Lit_BrokenApril: 11.45 minutes
# INFO:root:3:  Lit_MagicMountain: 6.02 minutes
# INFO:root:4:  Arg_PISARapaNui: 8.71 minutes
# INFO:root:5: Ins_HumanRights: 2.63 minutes
# INFO:root:obligatory break: 7.65 minutes
# INFO:root:6:  PopSci_MultiplEYE: 8.55 minutes
# INFO:root:7:  Lit_Alchemist: 7.4 minutes
# INFO:root:8:  Ins_LearningMobility: 11.13 minutes
# INFO:root:9:  Lit_Solaris: 8.82 minutes
# INFO:root:10:  PopSci_Caveman: 3.78 minutes
# INFO:root:fixation_trigger:experimenter_calibration_triggered found 5 times
# INFO:root:fixation_trigger:experimenter_calibration_triggered found at 607146.0
# INFO:root:fixation_trigger:experimenter_calibration_triggered found at 1184520.0
# INFO:root:fixation_trigger:experimenter_calibration_triggered found at 2180177.0
# INFO:root:fixation_trigger:experimenter_calibration_triggered found at 4348864.0
# INFO:root:fixation_trigger:experimenter_calibration_triggered found at 4967231.0
# INFO:root:optional_break found 8 times
# INFO:root:optional_break_duration: lasting 1.92 seconds found at 1031828.0
# INFO:root:optional_break_duration: lasting 196.54 seconds found at 1588450.0
# INFO:root:optional_break_duration: lasting 127.60 seconds found at 2058657.0
# INFO:root:optional_break_duration: lasting 87.34 seconds found at 2568070.0
# INFO:root:optional_break_duration: lasting 147.19 seconds found at 3708986.0
# INFO:root:optional_break_duration: lasting 165.48 seconds found at 4084825.0
# INFO:root:optional_break_duration: lasting 5.41 seconds found at 4648030.0
# INFO:root:optional_break_duration: lasting 93.84 seconds found at 5319962.0
# INFO:root:obligatory_break found 1 times
# INFO:root:obligatory_break_duration: lasting 351.51 seconds found at 3150421.0
# 10, MSG	176158.0 stimulus_order_version: 10
# INFO:root:No calibration after validation 10/17 at 3252361.0 with validation score 0.32
# INFO:root: creating plots for 005_RU_RU_1_ET1.
# performing sanity checks: 100%|██████████| 3/3 [15:42<00:00, 314.02s/it]

# %%
gaze.frame
# Out:
# shape: (10_015, 8)
# ┌────────┬────────┬──────────┬────────┬────────────────┬────────────────┬──────────┬───────────────┐
# │ time   ┆ pupil  ┆ activity ┆ screen ┆ trial          ┆ stimulus       ┆ practice ┆ pixel         │
# │ ---    ┆ ---    ┆ ---      ┆ ---    ┆ ---            ┆ ---            ┆ ---      ┆ ---           │
# │ i64    ┆ f64    ┆ str      ┆ str    ┆ str            ┆ str            ┆ bool     ┆ list[f64]     │
# ╞════════╪════════╪══════════╪════════╪════════════════╪════════════════╪══════════╪═══════════════╡
# │ 331571 ┆ 1330.0 ┆ reading  ┆ page_1 ┆ PRACTICE_trial ┆ Enc_WikiMoon_1 ┆ true     ┆ [50.4, 112.4] │
# │        ┆        ┆          ┆        ┆ _1             ┆ 3              ┆          ┆               │
# │ 331572 ┆ 1330.0 ┆ reading  ┆ page_1 ┆ PRACTICE_trial ┆ Enc_WikiMoon_1 ┆ true     ┆ [51.2, 112.3] │
# │        ┆        ┆          ┆        ┆ _1             ┆ 3              ┆          ┆               │
# │ 331573 ┆ 1329.0 ┆ reading  ┆ page_1 ┆ PRACTICE_trial ┆ Enc_WikiMoon_1 ┆ true     ┆ [52.0, 112.2] │
# │        ┆        ┆          ┆        ┆ _1             ┆ 3              ┆          ┆               │
# │ 331574 ┆ 1329.0 ┆ reading  ┆ page_1 ┆ PRACTICE_trial ┆ Enc_WikiMoon_1 ┆ true     ┆ [52.6, 112.3] │
# │        ┆        ┆          ┆        ┆ _1             ┆ 3              ┆          ┆               │
# │ 331575 ┆ 1327.0 ┆ reading  ┆ page_1 ┆ PRACTICE_trial ┆ Enc_WikiMoon_1 ┆ true     ┆ [52.4, 112.4] │
# │        ┆        ┆          ┆        ┆ _1             ┆ 3              ┆          ┆               │
# │ …      ┆ …      ┆ …        ┆ …      ┆ …              ┆ …              ┆ …        ┆ …             │
# │ 341581 ┆ 1207.0 ┆ reading  ┆ page_1 ┆ PRACTICE_trial ┆ Enc_WikiMoon_1 ┆ true     ┆ [170.8,       │
# │        ┆        ┆          ┆        ┆ _1             ┆ 3              ┆          ┆ 180.7]        │
# │ 341582 ┆ 1207.0 ┆ reading  ┆ page_1 ┆ PRACTICE_trial ┆ Enc_WikiMoon_1 ┆ true     ┆ [170.0,       │
# │        ┆        ┆          ┆        ┆ _1             ┆ 3              ┆          ┆ 180.6]        │
# │ 341583 ┆ 1208.0 ┆ reading  ┆ page_1 ┆ PRACTICE_trial ┆ Enc_WikiMoon_1 ┆ true     ┆ [169.7,       │
# │        ┆        ┆          ┆        ┆ _1             ┆ 3              ┆          ┆ 180.4]        │
# │ 341584 ┆ 1210.0 ┆ reading  ┆ page_1 ┆ PRACTICE_trial ┆ Enc_WikiMoon_1 ┆ true     ┆ [170.1,       │
# │        ┆        ┆          ┆        ┆ _1             ┆ 3              ┆          ┆ 180.3]        │
# │ 341585 ┆ 1210.0 ┆ reading  ┆ page_1 ┆ PRACTICE_trial ┆ Enc_WikiMoon_1 ┆ true     ┆ [171.1,       │
# │        ┆        ┆          ┆        ┆ _1             ┆ 3              ┆          ┆ 180.2]        │
# └────────┴────────┴──────────┴────────┴────────────────┴────────────────┴──────────┴───────────────┘

# %%
gaze.split(gaze.trial_columns)[0].frame
# Out:
# shape: (10_015, 10)
# ┌────────┬────────┬──────────┬────────┬───┬──────────┬───────────┬──────────────┬─────────────┐
# │ time   ┆ pupil  ┆ activity ┆ screen ┆ … ┆ practice ┆ pixel     ┆ position     ┆ velocity    │
# │ ---    ┆ ---    ┆ ---      ┆ ---    ┆   ┆ ---      ┆ ---       ┆ ---          ┆ ---         │
# │ i64    ┆ f64    ┆ str      ┆ str    ┆   ┆ bool     ┆ list[f64] ┆ list[f64]    ┆ list[f64]   │
# ╞════════╪════════╪══════════╪════════╪═══╪══════════╪═══════════╪══════════════╪═════════════╡
# │ 331571 ┆ 1330.0 ┆ reading  ┆ page_1 ┆ … ┆ true     ┆ [50.4,    ┆ [-22.73555,  ┆ [13.132353, │
# │        ┆        ┆          ┆        ┆   ┆          ┆ 112.4]    ┆ -11.112196]  ┆ 1.031506]   │
# │ 331572 ┆ 1330.0 ┆ reading  ┆ page_1 ┆ … ┆ true     ┆ [51.2,    ┆ [-22.717575, ┆ [13.228525, │
# │        ┆        ┆          ┆        ┆   ┆          ┆ 112.3]    ┆ -11.114733]  ┆ 1.004174]   │
# │ 331573 ┆ 1329.0 ┆ reading  ┆ page_1 ┆ … ┆ true     ┆ [52.0,    ┆ [-22.699596, ┆ [13.258349, │
# │        ┆        ┆          ┆        ┆   ┆          ┆ 112.2]    ┆ -11.11727]   ┆ 0.992228]   │
# │ 331574 ┆ 1329.0 ┆ reading  ┆ page_1 ┆ … ┆ true     ┆ [52.6,    ┆ [-22.686109, ┆ [13.228169, │
# │        ┆        ┆          ┆        ┆   ┆          ┆ 112.3]    ┆ -11.114733]  ┆ 1.006463]   │
# │ 331575 ┆ 1327.0 ┆ reading  ┆ page_1 ┆ … ┆ true     ┆ [52.4,    ┆ [-22.690605, ┆ [13.144118, │
# │        ┆        ┆          ┆        ┆   ┆          ┆ 112.4]    ┆ -11.112196]  ┆ 1.051474]   │
# │ …      ┆ …      ┆ …        ┆ …      ┆ … ┆ …        ┆ …         ┆ …            ┆ …           │
# │ 341581 ┆ 1207.0 ┆ reading  ┆ page_1 ┆ … ┆ true     ┆ [170.8,   ┆ [-19.978301, ┆ [-0.99292,  │
# │        ┆        ┆          ┆        ┆   ┆          ┆ 180.7]    ┆ -9.369592]   ┆ -0.881665]  │
# │ 341582 ┆ 1207.0 ┆ reading  ┆ page_1 ┆ … ┆ true     ┆ [170.0,   ┆ [-19.99696,  ┆ [-0.980888, │
# │        ┆        ┆          ┆        ┆   ┆          ┆ 180.6]    ┆ -9.372157]   ┆ -0.814339]  │
# │ 341583 ┆ 1208.0 ┆ reading  ┆ page_1 ┆ … ┆ true     ┆ [169.7,   ┆ [-20.003956, ┆ [-0.96062,  │
# │        ┆        ┆          ┆        ┆   ┆          ┆ 180.4]    ┆ -9.377287]   ┆ -0.772552]  │
# │ 341584 ┆ 1210.0 ┆ reading  ┆ page_1 ┆ … ┆ true     ┆ [170.1,   ┆ [-19.994628, ┆ [-0.937396, │
# │        ┆        ┆          ┆        ┆   ┆          ┆ 180.3]    ┆ -9.379852]   ┆ -0.73332]   │
# │ 341585 ┆ 1210.0 ┆ reading  ┆ page_1 ┆ … ┆ true     ┆ [171.1,   ┆ [-19.971303, ┆ [-0.905724, │
# │        ┆        ┆          ┆        ┆   ┆          ┆ 180.2]    ┆ -9.382417]   ┆ -0.690837]  │
# └────────┴────────┴──────────┴────────┴───┴──────────┴───────────┴──────────────┴─────────────┘

# %%
experiment.preprocess(gaze)

# %%
experiment.gaze.events.frame
# Out:
# shape: (273, 27)
# ┌────────────┬────────────┬────────┬──────────┬───┬────────────┬───────────┬───────────┬───────────┐
# │ trial      ┆ stimulus   ┆ screen ┆ name     ┆ … ┆ question_i ┆ location  ┆ amplitude ┆ peak_velo │
# │ ---        ┆ ---        ┆ ---    ┆ ---      ┆   ┆ mage_versi ┆ ---       ┆ _right    ┆ city_righ │
# │ str        ┆ str        ┆ str    ┆ str      ┆   ┆ on         ┆ list[f64] ┆ ---       ┆ t         │
# │            ┆            ┆        ┆          ┆   ┆ ---        ┆           ┆ f64       ┆ ---       │
# │            ┆            ┆        ┆          ┆   ┆ str        ┆           ┆           ┆ f64       │
# ╞════════════╪════════════╪════════╪══════════╪═══╪════════════╪═══════════╪═══════════╪═══════════╡
# │ PRACTICE_t ┆ Enc_WikiMo ┆ page_1 ┆ fixation ┆ … ┆ null       ┆ [68.84982 ┆ null      ┆ null      │
# │ rial_1     ┆ on_13      ┆        ┆          ┆   ┆            ┆ 4, 115.10 ┆           ┆           │
# │            ┆            ┆        ┆          ┆   ┆            ┆ 4401]     ┆           ┆           │
# │ PRACTICE_t ┆ Enc_WikiMo ┆ page_1 ┆ fixation ┆ … ┆ null       ┆ [68.84982 ┆ null      ┆ null      │
# │ rial_1     ┆ on_13      ┆        ┆          ┆   ┆            ┆ 4, 115.10 ┆           ┆           │
# │            ┆            ┆        ┆          ┆   ┆            ┆ 4401]     ┆           ┆           │
# │ PRACTICE_t ┆ Enc_WikiMo ┆ page_1 ┆ fixation ┆ … ┆ question_i ┆ [132.9444 ┆ null      ┆ null      │
# │ rial_1     ┆ on_13      ┆        ┆          ┆   ┆ mages_vers ┆ 44, 107.8 ┆           ┆           │
# │            ┆            ┆        ┆          ┆   ┆ ion_1      ┆ 23392]    ┆           ┆           │
# │ PRACTICE_t ┆ Enc_WikiMo ┆ page_1 ┆ fixation ┆ … ┆ question_i ┆ [132.9444 ┆ null      ┆ null      │
# │ rial_1     ┆ on_13      ┆        ┆          ┆   ┆ mages_vers ┆ 44, 107.8 ┆           ┆           │
# │            ┆            ┆        ┆          ┆   ┆ ion_1      ┆ 23392]    ┆           ┆           │
# │ PRACTICE_t ┆ Enc_WikiMo ┆ page_1 ┆ fixation ┆ … ┆ question_i ┆ [163.3873 ┆ null      ┆ null      │
# │ rial_1     ┆ on_13      ┆        ┆          ┆   ┆ mages_vers ┆ 49, 161.5 ┆           ┆           │
# │            ┆            ┆        ┆          ┆   ┆ ion_1      ┆ 14458]    ┆           ┆           │
# │ …          ┆ …          ┆ …      ┆ …        ┆ … ┆ …          ┆ …         ┆ …         ┆ …         │
# │ PRACTICE_t ┆ Enc_WikiMo ┆ page_1 ┆ saccade  ┆ … ┆ null       ┆ null      ┆ 0.094757  ┆ 5.952321  │
# │ rial_1     ┆ on_13      ┆        ┆          ┆   ┆            ┆           ┆           ┆           │
# │ PRACTICE_t ┆ Enc_WikiMo ┆ page_1 ┆ saccade  ┆ … ┆ null       ┆ null      ┆ 1.307814  ┆ 23.000019 │
# │ rial_1     ┆ on_13      ┆        ┆          ┆   ┆            ┆           ┆           ┆           │
# │ PRACTICE_t ┆ Enc_WikiMo ┆ page_1 ┆ saccade  ┆ … ┆ null       ┆ null      ┆ 0.128677  ┆ 6.872487  │
# │ rial_1     ┆ on_13      ┆        ┆          ┆   ┆            ┆           ┆           ┆           │
# │ PRACTICE_t ┆ Enc_WikiMo ┆ page_1 ┆ saccade  ┆ … ┆ null       ┆ null      ┆ 0.899746  ┆ 20.816958 │
# │ rial_1     ┆ on_13      ┆        ┆          ┆   ┆            ┆           ┆           ┆           │
# │ PRACTICE_t ┆ Enc_WikiMo ┆ page_1 ┆ saccade  ┆ … ┆ null       ┆ null      ┆ 10.385536 ┆ 186.62514 │
# │ rial_1     ┆ on_13      ┆        ┆          ┆   ┆            ┆           ┆           ┆ 6         │
# └────────────┴────────────┴────────┴──────────┴───┴────────────┴───────────┴───────────┴───────────┘

# %%
import polars as pl
gaze.events.frame = gaze.events.frame.filter(pl.col("name") == "fixation")

# %%
gaze.events.frame
# Out:
# shape: (148, 27)
# ┌────────────┬────────────┬────────┬──────────┬───┬────────────┬───────────┬───────────┬───────────┐
# │ trial      ┆ stimulus   ┆ screen ┆ name     ┆ … ┆ question_i ┆ location  ┆ amplitude ┆ peak_velo │
# │ ---        ┆ ---        ┆ ---    ┆ ---      ┆   ┆ mage_versi ┆ ---       ┆ _right    ┆ city_righ │
# │ str        ┆ str        ┆ str    ┆ str      ┆   ┆ on         ┆ list[f64] ┆ ---       ┆ t         │
# │            ┆            ┆        ┆          ┆   ┆ ---        ┆           ┆ f64       ┆ ---       │
# │            ┆            ┆        ┆          ┆   ┆ str        ┆           ┆           ┆ f64       │
# ╞════════════╪════════════╪════════╪══════════╪═══╪════════════╪═══════════╪═══════════╪═══════════╡
# │ PRACTICE_t ┆ Enc_WikiMo ┆ page_1 ┆ fixation ┆ … ┆ null       ┆ [68.84982 ┆ null      ┆ null      │
# │ rial_1     ┆ on_13      ┆        ┆          ┆   ┆            ┆ 4, 115.10 ┆           ┆           │
# │            ┆            ┆        ┆          ┆   ┆            ┆ 4401]     ┆           ┆           │
# │ PRACTICE_t ┆ Enc_WikiMo ┆ page_1 ┆ fixation ┆ … ┆ null       ┆ [68.84982 ┆ null      ┆ null      │
# │ rial_1     ┆ on_13      ┆        ┆          ┆   ┆            ┆ 4, 115.10 ┆           ┆           │
# │            ┆            ┆        ┆          ┆   ┆            ┆ 4401]     ┆           ┆           │
# │ PRACTICE_t ┆ Enc_WikiMo ┆ page_1 ┆ fixation ┆ … ┆ question_i ┆ [132.9444 ┆ null      ┆ null      │
# │ rial_1     ┆ on_13      ┆        ┆          ┆   ┆ mages_vers ┆ 44, 107.8 ┆           ┆           │
# │            ┆            ┆        ┆          ┆   ┆ ion_1      ┆ 23392]    ┆           ┆           │
# │ PRACTICE_t ┆ Enc_WikiMo ┆ page_1 ┆ fixation ┆ … ┆ question_i ┆ [132.9444 ┆ null      ┆ null      │
# │ rial_1     ┆ on_13      ┆        ┆          ┆   ┆ mages_vers ┆ 44, 107.8 ┆           ┆           │
# │            ┆            ┆        ┆          ┆   ┆ ion_1      ┆ 23392]    ┆           ┆           │
# │ PRACTICE_t ┆ Enc_WikiMo ┆ page_1 ┆ fixation ┆ … ┆ question_i ┆ [163.3873 ┆ null      ┆ null      │
# │ rial_1     ┆ on_13      ┆        ┆          ┆   ┆ mages_vers ┆ 49, 161.5 ┆           ┆           │
# │            ┆            ┆        ┆          ┆   ┆ ion_1      ┆ 14458]    ┆           ┆           │
# │ …          ┆ …          ┆ …      ┆ …        ┆ … ┆ …          ┆ …         ┆ …         ┆ …         │
# │ PRACTICE_t ┆ Enc_WikiMo ┆ page_1 ┆ fixation ┆ … ┆ null       ┆ [150.9005 ┆ null      ┆ null      │
# │ rial_1     ┆ on_13      ┆        ┆          ┆   ┆            ┆ 32, 584.1 ┆           ┆           │
# │            ┆            ┆        ┆          ┆   ┆            ┆ 17553]    ┆           ┆           │
# │ PRACTICE_t ┆ Enc_WikiMo ┆ page_1 ┆ fixation ┆ … ┆ null       ┆ [123.6859 ┆ null      ┆ null      │
# │ rial_1     ┆ on_13      ┆        ┆          ┆   ┆            ┆ 53, 579.3 ┆           ┆           │
# │            ┆            ┆        ┆          ┆   ┆            ┆ 44147]    ┆           ┆           │
# │ PRACTICE_t ┆ Enc_WikiMo ┆ page_1 ┆ fixation ┆ … ┆ null       ┆ [123.6859 ┆ null      ┆ null      │
# │ rial_1     ┆ on_13      ┆        ┆          ┆   ┆            ┆ 53, 579.3 ┆           ┆           │
# │            ┆            ┆        ┆          ┆   ┆            ┆ 44147]    ┆           ┆           │
# │ PRACTICE_t ┆ Enc_WikiMo ┆ page_1 ┆ fixation ┆ … ┆ null       ┆ [153.6649 ┆ null      ┆ null      │
# │ rial_1     ┆ on_13      ┆        ┆          ┆   ┆            ┆ 81, 576.4 ┆           ┆           │
# │            ┆            ┆        ┆          ┆   ┆            ┆ 34241]    ┆           ┆           │
# │ PRACTICE_t ┆ Enc_WikiMo ┆ page_1 ┆ fixation ┆ … ┆ null       ┆ [153.6649 ┆ null      ┆ null      │
# │ rial_1     ┆ on_13      ┆        ┆          ┆   ┆            ┆ 81, 576.4 ┆           ┆           │
# │            ┆            ┆        ┆          ┆   ┆            ┆ 34241]    ┆           ┆           │
# └────────────┴────────────┴────────┴──────────┴───┴────────────┴───────────┴───────────┴───────────┘

# %%
test_text = multipleye.sessions["005_RU_RU_1_ET1"]["session_stimuli"][10].text_stimulus

#multipleye.sessions["005_RU_RU_1_ET1"]["session_stimuli"][10].questions
test_text.page_column
# Out:
# 'page'

# %%
test_text.aois= test_text.aois.filter(pl.col("page") == "page_1")
test_text.split(gaze.trial_columns)
# Out:
# ---------------------------------------------------------------------------
# ColumnNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10636\2820956139.py in ?()
#       1 test_text.aois= test_text.aois.filter(pl.col("page") == "page_1")
# ----> 2 test_text.split(gaze.trial_columns)
#
# ~\PycharmProjects\multipleye-preprocessing\venv\Lib\site-packages\pymovements\stimulus\text.py in ?(self, by)
#     110                 end_x_column=self.end_x_column,
#     111                 end_y_column=self.end_y_column,
#     112                 page_column=self.page_column,
#     113             )
# --> 114             for df in self.aois.partition_by(by=by, as_dict=False)
#     115         ]
#
# ~\PycharmProjects\multipleye-preprocessing\venv\Lib\site-packages\polars\dataframe\frame.py in ?(self, by, maintain_order, include_key, as_dict, *more_by)
#    9329         by_parsed = _expand_selectors(self, by, *more_by)
#    9330
#    9331         partitions = [
#    9332             self._from_pydf(_df)
# -> 9333             for _df in self._df.partition_by(by_parsed, maintain_order, include_key)
#    9334         ]
#    9335
#    9336         if as_dict:
#
# ColumnNotFoundError: "trial" not found

# %%
test_text.aois
# Out:
# shape: (0, 13)
# ┌──────────┬──────┬────────────┬────────────┬───┬──────────┬────────────────┬──────┬───────────────┐
# │ char_idx ┆ char ┆ top_left_x ┆ top_left_y ┆ … ┆ word_idx ┆ word_idx_in_li ┆ word ┆ question_imag │
# │ ---      ┆ ---  ┆ ---        ┆ ---        ┆   ┆ ---      ┆ ne             ┆ ---  ┆ e_version     │
# │ i64      ┆ str  ┆ f64        ┆ f64        ┆   ┆ i64      ┆ ---            ┆ str  ┆ ---           │
# │          ┆      ┆            ┆            ┆   ┆          ┆ i64            ┆      ┆ str           │
# ╞══════════╪══════╪════════════╪════════════╪═══╪══════════╪════════════════╪══════╪═══════════════╡
# └──────────┴──────┴────────────┴────────────┴───┴──────────┴────────────────┴──────┴───────────────┘

# %%
gaze.events.map_to_aois(test_text)
# Out:
# 37it [00:00, 1746.05it/s]

# %%
gaze.events.frame
# Out:
# shape: (148, 27)
# ┌────────────┬────────────┬────────┬──────────┬───┬────────────┬───────────┬───────────┬───────────┐
# │ trial      ┆ stimulus   ┆ screen ┆ name     ┆ … ┆ question_i ┆ location  ┆ amplitude ┆ peak_velo │
# │ ---        ┆ ---        ┆ ---    ┆ ---      ┆   ┆ mage_versi ┆ ---       ┆ _right    ┆ city_righ │
# │ str        ┆ str        ┆ str    ┆ str      ┆   ┆ on         ┆ list[f64] ┆ ---       ┆ t         │
# │            ┆            ┆        ┆          ┆   ┆ ---        ┆           ┆ f64       ┆ ---       │
# │            ┆            ┆        ┆          ┆   ┆ str        ┆           ┆           ┆ f64       │
# ╞════════════╪════════════╪════════╪══════════╪═══╪════════════╪═══════════╪═══════════╪═══════════╡
# │ PRACTICE_t ┆ Enc_WikiMo ┆ page_1 ┆ fixation ┆ … ┆ null       ┆ [68.84982 ┆ null      ┆ null      │
# │ rial_1     ┆ on_13      ┆        ┆          ┆   ┆            ┆ 4, 115.10 ┆           ┆           │
# │            ┆            ┆        ┆          ┆   ┆            ┆ 4401]     ┆           ┆           │
# │ PRACTICE_t ┆ Enc_WikiMo ┆ page_1 ┆ fixation ┆ … ┆ null       ┆ [68.84982 ┆ null      ┆ null      │
# │ rial_1     ┆ on_13      ┆        ┆          ┆   ┆            ┆ 4, 115.10 ┆           ┆           │
# │            ┆            ┆        ┆          ┆   ┆            ┆ 4401]     ┆           ┆           │
# │ PRACTICE_t ┆ Enc_WikiMo ┆ page_1 ┆ fixation ┆ … ┆ question_i ┆ [132.9444 ┆ null      ┆ null      │
# │ rial_1     ┆ on_13      ┆        ┆          ┆   ┆ mages_vers ┆ 44, 107.8 ┆           ┆           │
# │            ┆            ┆        ┆          ┆   ┆ ion_1      ┆ 23392]    ┆           ┆           │
# │ PRACTICE_t ┆ Enc_WikiMo ┆ page_1 ┆ fixation ┆ … ┆ question_i ┆ [132.9444 ┆ null      ┆ null      │
# │ rial_1     ┆ on_13      ┆        ┆          ┆   ┆ mages_vers ┆ 44, 107.8 ┆           ┆           │
# │            ┆            ┆        ┆          ┆   ┆ ion_1      ┆ 23392]    ┆           ┆           │
# │ PRACTICE_t ┆ Enc_WikiMo ┆ page_1 ┆ fixation ┆ … ┆ question_i ┆ [163.3873 ┆ null      ┆ null      │
# │ rial_1     ┆ on_13      ┆        ┆          ┆   ┆ mages_vers ┆ 49, 161.5 ┆           ┆           │
# │            ┆            ┆        ┆          ┆   ┆ ion_1      ┆ 14458]    ┆           ┆           │
# │ …          ┆ …          ┆ …      ┆ …        ┆ … ┆ …          ┆ …         ┆ …         ┆ …         │
# │ PRACTICE_t ┆ Enc_WikiMo ┆ page_1 ┆ fixation ┆ … ┆ null       ┆ [150.9005 ┆ null      ┆ null      │
# │ rial_1     ┆ on_13      ┆        ┆          ┆   ┆            ┆ 32, 584.1 ┆           ┆           │
# │            ┆            ┆        ┆          ┆   ┆            ┆ 17553]    ┆           ┆           │
# │ PRACTICE_t ┆ Enc_WikiMo ┆ page_1 ┆ fixation ┆ … ┆ null       ┆ [123.6859 ┆ null      ┆ null      │
# │ rial_1     ┆ on_13      ┆        ┆          ┆   ┆            ┆ 53, 579.3 ┆           ┆           │
# │            ┆            ┆        ┆          ┆   ┆            ┆ 44147]    ┆           ┆           │
# │ PRACTICE_t ┆ Enc_WikiMo ┆ page_1 ┆ fixation ┆ … ┆ null       ┆ [123.6859 ┆ null      ┆ null      │
# │ rial_1     ┆ on_13      ┆        ┆          ┆   ┆            ┆ 53, 579.3 ┆           ┆           │
# │            ┆            ┆        ┆          ┆   ┆            ┆ 44147]    ┆           ┆           │
# │ PRACTICE_t ┆ Enc_WikiMo ┆ page_1 ┆ fixation ┆ … ┆ null       ┆ [153.6649 ┆ null      ┆ null      │
# │ rial_1     ┆ on_13      ┆        ┆          ┆   ┆            ┆ 81, 576.4 ┆           ┆           │
# │            ┆            ┆        ┆          ┆   ┆            ┆ 34241]    ┆           ┆           │
# │ PRACTICE_t ┆ Enc_WikiMo ┆ page_1 ┆ fixation ┆ … ┆ null       ┆ [153.6649 ┆ null      ┆ null      │
# │ rial_1     ┆ on_13      ┆        ┆          ┆   ┆            ┆ 81, 576.4 ┆           ┆           │
# │            ┆            ┆        ┆          ┆   ┆            ┆ 34241]    ┆           ┆           │
# └────────────┴────────────┴────────┴──────────┴───┴────────────┴───────────┴───────────┴───────────┘

# %%
first = multipleye.sessions["005_RU_RU_1_ET1"]["session_stimuli"][0].text_stimulus

for stimulus in multipleye.sessions["005_RU_RU_1_ET1"]["session_stimuli"][0:]:
    first.aois.vstack(stimulus.text_stimulus.aois)

# %%
test_text = multipleye.sessions["005_RU_RU_1_ET1"]["session_stimuli"][0]

# %%
test_text.text_stimulus.aois
# Out:
# shape: (25_484, 13)
# ┌──────────┬──────┬────────────┬────────────┬───┬──────────┬──────────────┬──────────┬─────────────┐
# │ char_idx ┆ char ┆ top_left_x ┆ top_left_y ┆ … ┆ word_idx ┆ word_idx_in_ ┆ word     ┆ question_im │
# │ ---      ┆ ---  ┆ ---        ┆ ---        ┆   ┆ ---      ┆ line         ┆ ---      ┆ age_version │
# │ i64      ┆ str  ┆ f64        ┆ f64        ┆   ┆ i64      ┆ ---          ┆ str      ┆ ---         │
# │          ┆      ┆            ┆            ┆   ┆          ┆ i64          ┆          ┆ str         │
# ╞══════════╪══════╪════════════╪════════════╪═══╪══════════╪══════════════╪══════════╪═════════════╡
# │ 0        ┆ Ч    ┆ 83.0       ┆ 90.0       ┆ … ┆ 0        ┆ 0            ┆ Что      ┆ question_im │
# │          ┆      ┆            ┆            ┆   ┆          ┆              ┆          ┆ ages_versio │
# │          ┆      ┆            ┆            ┆   ┆          ┆              ┆          ┆ n_1         │
# │ 1        ┆ т    ┆ 97.0       ┆ 90.0       ┆ … ┆ 0        ┆ 0            ┆ Что      ┆ question_im │
# │          ┆      ┆            ┆            ┆   ┆          ┆              ┆          ┆ ages_versio │
# │          ┆      ┆            ┆            ┆   ┆          ┆              ┆          ┆ n_1         │
# │ 2        ┆ о    ┆ 111.0      ┆ 90.0       ┆ … ┆ 0        ┆ 0            ┆ Что      ┆ question_im │
# │          ┆      ┆            ┆            ┆   ┆          ┆              ┆          ┆ ages_versio │
# │          ┆      ┆            ┆            ┆   ┆          ┆              ┆          ┆ n_1         │
# │ 3        ┆      ┆ 125.0      ┆ 90.0       ┆ … ┆ 0        ┆ 0            ┆          ┆ question_im │
# │          ┆      ┆            ┆            ┆   ┆          ┆              ┆          ┆ ages_versio │
# │          ┆      ┆            ┆            ┆   ┆          ┆              ┆          ┆ n_1         │
# │ 4        ┆ т    ┆ 139.0      ┆ 90.0       ┆ … ┆ 1        ┆ 1            ┆ такое    ┆ question_im │
# │          ┆      ┆            ┆            ┆   ┆          ┆              ┆          ┆ ages_versio │
# │          ┆      ┆            ┆            ┆   ┆          ┆              ┆          ┆ n_1         │
# │ …        ┆ …    ┆ …          ┆ …          ┆ … ┆ …        ┆ …            ┆ …        ┆ …           │
# │ 348      ┆ с    ┆ 615.0      ┆ 472.8      ┆ … ┆ 51       ┆ 6            ┆ Спасибо! ┆             │
# │ 349      ┆ и    ┆ 629.0      ┆ 472.8      ┆ … ┆ 51       ┆ 6            ┆ Спасибо! ┆             │
# │ 350      ┆ б    ┆ 643.0      ┆ 472.8      ┆ … ┆ 51       ┆ 6            ┆ Спасибо! ┆             │
# │ 351      ┆ о    ┆ 657.0      ┆ 472.8      ┆ … ┆ 51       ┆ 6            ┆ Спасибо! ┆             │
# │ 352      ┆ !    ┆ 671.0      ┆ 472.8      ┆ … ┆ 51       ┆ 6            ┆ Спасибо! ┆             │
# └──────────┴──────┴────────────┴────────────┴───┴──────────┴──────────────┴──────────┴─────────────┘

# %%
import polars as pl
gaze.events.frame.filter(pl.col("name") == "fixation")
# Out:
# shape: (7_001, 11)
# ┌───────────┬───────────┬───────────┬──────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ trial     ┆ stimulus  ┆ screen    ┆ name     ┆ … ┆ amplitude ┆ peak_velo ┆ location_ ┆ location_ │
# │ ---       ┆ ---       ┆ ---       ┆ ---      ┆   ┆ ---       ┆ city      ┆ x         ┆ y         │
# │ str       ┆ str       ┆ str       ┆ str      ┆   ┆ f64       ┆ ---       ┆ ---       ┆ ---       │
# │           ┆           ┆           ┆          ┆   ┆           ┆ f64       ┆ f64       ┆ f64       │
# ╞═══════════╪═══════════╪═══════════╪══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ PRACTICE_ ┆ Enc_WikiM ┆ page_1    ┆ fixation ┆ … ┆ null      ┆ null      ┆ 68.849824 ┆ 115.10440 │
# │ trial_1   ┆ oon_13    ┆           ┆          ┆   ┆           ┆           ┆           ┆ 1         │
# │ PRACTICE_ ┆ Enc_WikiM ┆ page_1    ┆ fixation ┆ … ┆ null      ┆ null      ┆ 132.94444 ┆ 107.82339 │
# │ trial_1   ┆ oon_13    ┆           ┆          ┆   ┆           ┆           ┆ 4         ┆ 2         │
# │ PRACTICE_ ┆ Enc_WikiM ┆ page_1    ┆ fixation ┆ … ┆ null      ┆ null      ┆ 163.38734 ┆ 161.51445 │
# │ trial_1   ┆ oon_13    ┆           ┆          ┆   ┆           ┆           ┆ 9         ┆ 8         │
# │ PRACTICE_ ┆ Enc_WikiM ┆ page_1    ┆ fixation ┆ … ┆ null      ┆ null      ┆ 121.98493 ┆ 163.69178 │
# │ trial_1   ┆ oon_13    ┆           ┆          ┆   ┆           ┆           ┆ 2         ┆ 1         │
# │ PRACTICE_ ┆ Enc_WikiM ┆ page_1    ┆ fixation ┆ … ┆ null      ┆ null      ┆ 193.16946 ┆ 200.08503 │
# │ trial_1   ┆ oon_13    ┆           ┆          ┆   ┆           ┆           ┆ 1         ┆           │
# │ …         ┆ …         ┆ …         ┆ …        ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ trial_10  ┆ PopSci_Ca ┆ question_ ┆ fixation ┆ … ┆ null      ┆ null      ┆ 355.76201 ┆ 215.06279 │
# │           ┆ veman_12  ┆ 12131     ┆          ┆   ┆           ┆           ┆ 6         ┆ 1         │
# │ trial_10  ┆ PopSci_Ca ┆ question_ ┆ fixation ┆ … ┆ null      ┆ null      ┆ 1034.1263 ┆ 116.45736 │
# │           ┆ veman_12  ┆ 12131     ┆          ┆   ┆           ┆           ┆ 96        ┆           │
# │ trial_10  ┆ PopSci_Ca ┆ question_ ┆ fixation ┆ … ┆ null      ┆ null      ┆ 872.97261 ┆ 105.40059 │
# │           ┆ veman_12  ┆ 12131     ┆          ┆   ┆           ┆           ┆ 9         ┆ 5         │
# │ trial_10  ┆ PopSci_Ca ┆ question_ ┆ fixation ┆ … ┆ null      ┆ null      ┆ 1111.7761 ┆ 119.50833 │
# │           ┆ veman_12  ┆ 12131     ┆          ┆   ┆           ┆           ┆ 11        ┆ 3         │
# │ trial_10  ┆ PopSci_Ca ┆ question_ ┆ fixation ┆ … ┆ null      ┆ null      ┆ 227.95    ┆ 183.7225  │
# │           ┆ veman_12  ┆ 12131     ┆          ┆   ┆           ┆           ┆           ┆           │
# └───────────┴───────────┴───────────┴──────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
gaze.events.frame = gaze.events.frame.filter(pl.col("name") == "fixation")

# %%
gaze.split(gaze.trial_columns)[0].events.frame
# Out:
# shape: (0, 7)
# ┌───────┬──────────┬────────┬──────┬───────┬────────┬──────────┐
# │ trial ┆ stimulus ┆ screen ┆ name ┆ onset ┆ offset ┆ duration │
# │ ---   ┆ ---      ┆ ---    ┆ ---  ┆ ---   ┆ ---    ┆ ---      │
# │ str   ┆ str      ┆ str    ┆ str  ┆ i64   ┆ i64    ┆ i64      │
# ╞═══════╪══════════╪════════╪══════╪═══════╪════════╪══════════╡
# └───────┴──────────┴────────┴──────┴───────┴────────┴──────────┘

# %%
gaze.split(gaze.trial_columns)[1].frame
# Out:
# shape: (15_204, 11)
# ┌────────┬────────┬──────────┬─────────────┬───┬────────────┬────────────┬────────────┬────────────┐
# │ time   ┆ pupil  ┆ activity ┆ stimulus    ┆ … ┆ session    ┆ pixel      ┆ position   ┆ velocity   │
# │ ---    ┆ ---    ┆ ---      ┆ ---         ┆   ┆ ---        ┆ ---        ┆ ---        ┆ ---        │
# │ i64    ┆ f64    ┆ str      ┆ str         ┆   ┆ str        ┆ list[f64]  ┆ list[f64]  ┆ list[f64]  │
# ╞════════╪════════╪══════════╪═════════════╪═══╪════════════╪════════════╪════════════╪════════════╡
# │ 345355 ┆ 1313.0 ┆ reading  ┆ Enc_WikiMoo ┆ … ┆ 005_RU_RU_ ┆ [55.8,     ┆ [-22.61413 ┆ [-0.104424 │
# │        ┆        ┆          ┆ n_13        ┆   ┆ 1_ET1      ┆ 111.9]     ┆ 1, -11.124 ┆ ,          │
# │        ┆        ┆          ┆             ┆   ┆            ┆            ┆ 881]       ┆ -0.243108] │
# │ 345356 ┆ 1312.0 ┆ reading  ┆ Enc_WikiMoo ┆ … ┆ 005_RU_RU_ ┆ [56.0,     ┆ [-22.60963 ┆ [-0.105446 │
# │        ┆        ┆          ┆ n_13        ┆   ┆ 1_ET1      ┆ 111.8]     ┆ , -11.1274 ┆ ,          │
# │        ┆        ┆          ┆             ┆   ┆            ┆            ┆ 18]        ┆ -0.249077] │
# │ 345357 ┆ 1312.0 ┆ reading  ┆ Enc_WikiMoo ┆ … ┆ 005_RU_RU_ ┆ [56.5,     ┆ [-22.59837 ┆ [-0.071026 │
# │        ┆        ┆          ┆ n_13        ┆   ┆ 1_ET1      ┆ 111.7]     ┆ 6, -11.129 ┆ ,          │
# │        ┆        ┆          ┆             ┆   ┆            ┆            ┆ 955]       ┆ -0.24265]  │
# │ 345358 ┆ 1312.0 ┆ reading  ┆ Enc_WikiMoo ┆ … ┆ 005_RU_RU_ ┆ [56.9,     ┆ [-22.58937 ┆ [-0.028048 │
# │        ┆        ┆          ┆ n_13        ┆   ┆ 1_ET1      ┆ 111.6]     ┆ 1, -11.132 ┆ ,          │
# │        ┆        ┆          ┆             ┆   ┆            ┆            ┆ 491]       ┆ -0.212806] │
# │ 345359 ┆ 1312.0 ┆ reading  ┆ Enc_WikiMoo ┆ … ┆ 005_RU_RU_ ┆ [56.7,     ┆ [-22.59387 ┆ [0.017985, │
# │        ┆        ┆          ┆ n_13        ┆   ┆ 1_ET1      ┆ 111.6]     ┆ 4, -11.132 ┆ -0.171942] │
# │        ┆        ┆          ┆             ┆   ┆            ┆            ┆ 491]       ┆            │
# │ …      ┆ …      ┆ …        ┆ …           ┆ … ┆ …          ┆ …          ┆ …          ┆ …          │
# │ 360554 ┆ 1329.0 ┆ reading  ┆ Enc_WikiMoo ┆ … ┆ 005_RU_RU_ ┆ [109.1,    ┆ [-21.40424 ┆ [25.025436 │
# │        ┆        ┆          ┆ n_13        ┆   ┆ 1_ET1      ┆ 579.7]     ┆ 8,         ┆ , -40.9021 │
# │        ┆        ┆          ┆             ┆   ┆            ┆            ┆ 1.059109]  ┆ 59]        │
# │ 360555 ┆ 1328.0 ┆ reading  ┆ Enc_WikiMoo ┆ … ┆ 005_RU_RU_ ┆ [110.0,    ┆ [-21.38364 ┆ [24.297211 │
# │        ┆        ┆          ┆ n_13        ┆   ┆ 1_ET1      ┆ 577.2]     ┆ 2,         ┆ , -40.1406 │
# │        ┆        ┆          ┆             ┆   ┆            ┆            ┆ 0.993257]  ┆ 99]        │
# │ 360556 ┆ 1328.0 ┆ reading  ┆ Enc_WikiMoo ┆ … ┆ 005_RU_RU_ ┆ [110.5,    ┆ [-21.37219 ┆ [23.461429 │
# │        ┆        ┆          ┆ n_13        ┆   ┆ 1_ET1      ┆ 575.3]     ┆ 2,         ┆ , -39.2396 │
# │        ┆        ┆          ┆             ┆   ┆            ┆            ┆ 0.943208]  ┆ 35]        │
# │ 360557 ┆ 1328.0 ┆ reading  ┆ Enc_WikiMoo ┆ … ┆ 005_RU_RU_ ┆ [110.9,    ┆ [-21.36303 ┆ [22.511956 │
# │        ┆        ┆          ┆ n_13        ┆   ┆ 1_ET1      ┆ 574.3]     ┆ ,          ┆ , -38.1925 │
# │        ┆        ┆          ┆             ┆   ┆            ┆            ┆ 0.916866]  ┆ 39]        │
# │ 360558 ┆ 1326.0 ┆ reading  ┆ Enc_WikiMoo ┆ … ┆ 005_RU_RU_ ┆ [111.1,    ┆ [-21.35844 ┆ [21.463723 │
# │        ┆        ┆          ┆ n_13        ┆   ┆ 1_ET1      ┆ 574.1]     ┆ 9,         ┆ , -36.9741 │
# │        ┆        ┆          ┆             ┆   ┆            ┆            ┆ 0.911598]  ┆ 81]        │
# └────────┴────────┴──────────┴─────────────┴───┴────────────┴────────────┴────────────┴────────────┘

# %%
gaze.events.frame
# Out:
# shape: (143_059, 24)
# ┌────────────┬────────────┬────────┬──────────┬───┬──────────┬────────────┬────────────┬───────────┐
# │ trial      ┆ stimulus   ┆ screen ┆ name     ┆ … ┆ word_idx ┆ word_idx_i ┆ word       ┆ question_ │
# │ ---        ┆ ---        ┆ ---    ┆ ---      ┆   ┆ ---      ┆ n_line     ┆ ---        ┆ image_ver │
# │ str        ┆ str        ┆ str    ┆ str      ┆   ┆ i64      ┆ ---        ┆ str        ┆ sion      │
# │            ┆            ┆        ┆          ┆   ┆          ┆ i64        ┆            ┆ ---       │
# │            ┆            ┆        ┆          ┆   ┆          ┆            ┆            ┆ str       │
# ╞════════════╪════════════╪════════╪══════════╪═══╪══════════╪════════════╪════════════╪═══════════╡
# │ PRACTICE_t ┆ Enc_WikiMo ┆ page_1 ┆ fixation ┆ … ┆ null     ┆ null       ┆ null       ┆ null      │
# │ rial_1     ┆ on_13      ┆        ┆          ┆   ┆          ┆            ┆            ┆           │
# │ PRACTICE_t ┆ Enc_WikiMo ┆ page_1 ┆ fixation ┆ … ┆ 0        ┆ 0          ┆            ┆ question_ │
# │ rial_1     ┆ on_13      ┆        ┆          ┆   ┆          ┆            ┆            ┆ images_ve │
# │            ┆            ┆        ┆          ┆   ┆          ┆            ┆            ┆ rsion_1   │
# │ PRACTICE_t ┆ Enc_WikiMo ┆ page_1 ┆ fixation ┆ … ┆ 0        ┆ 0          ┆            ┆ question_ │
# │ rial_1     ┆ on_13      ┆        ┆          ┆   ┆          ┆            ┆            ┆ images_ve │
# │            ┆            ┆        ┆          ┆   ┆          ┆            ┆            ┆ rsion_1   │
# │ PRACTICE_t ┆ Enc_WikiMo ┆ page_1 ┆ fixation ┆ … ┆ 0        ┆ 0          ┆ Почему     ┆ question_ │
# │ rial_1     ┆ on_13      ┆        ┆          ┆   ┆          ┆            ┆            ┆ images_ve │
# │            ┆            ┆        ┆          ┆   ┆          ┆            ┆            ┆ rsion_1   │
# │ PRACTICE_t ┆ Enc_WikiMo ┆ page_1 ┆ fixation ┆ … ┆ 0        ┆ 0          ┆ Какова     ┆ question_ │
# │ rial_1     ┆ on_13      ┆        ┆          ┆   ┆          ┆            ┆            ┆ images_ve │
# │            ┆            ┆        ┆          ┆   ┆          ┆            ┆            ┆ rsion_1   │
# │ …          ┆ …          ┆ …      ┆ …        ┆ … ┆ …        ┆ …          ┆ …          ┆ …         │
# │ null       ┆ null       ┆ null   ┆ null     ┆ … ┆ 10       ┆ 10         ┆ по-прежнем ┆           │
# │            ┆            ┆        ┆          ┆   ┆          ┆            ┆ у          ┆           │
# │ null       ┆ null       ┆ null   ┆ null     ┆ … ┆ 9        ┆ 9          ┆            ┆           │
# │ null       ┆ null       ┆ null   ┆ null     ┆ … ┆ 11       ┆ 11         ┆            ┆           │
# │ null       ┆ null       ┆ null   ┆ null     ┆ … ┆ 8        ┆ 8          ┆ содержащий ┆           │
# │ null       ┆ null       ┆ null   ┆ null     ┆ … ┆ null     ┆ null       ┆ null       ┆ null      │
# └────────────┴────────────┴────────┴──────────┴───┴──────────┴────────────┴────────────┴───────────┘

# %%
multipleye.create_sanity_check_report("016_ET_EE_1_ET1")

# %%
multipleye.create_sanity_check_report(plotting= True)

# %%
multipleye.create_gaze_frame("020_ET_EE_1_ET1")

# %%
multipleye.create_sanity_check_report("002_RU_RU_1_ET1")
# Out:
# performing sanity checks:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\saphi\PycharmProjects\multipleye-preprocessing\data\MultiplEYE_RU_RU_NewYork_1_2025\eye-tracking-sessions\quality_reports\002_RU_RU_1_ET1\002_RU_RU_1_ET1_gaze.pkl
# <class 'pathlib.WindowsPath'>
# <_io.BufferedReader name='C:\\Users\\saphi\\PycharmProjects\\multipleye-preprocessing\\data\\MultiplEYE_RU_RU_NewYork_1_2025\\eye-tracking-sessions\\quality_reports\\002_RU_RU_1_ET1\\002_RU_RU_1_ET1_gaze.pkl'>
# INFO:root:Correct answers for PopSci_MultiplEYE: 4 out of 6 answers
# INFO:root:Correct answers for Ins_HumanRights: 2 out of 6 answers
# INFO:root:Correct answers for Ins_LearningMobility: 1 out of 6 answers
# INFO:root:Correct answers for Lit_Alchemist: 4 out of 6 answers
# INFO:root:Correct answers for Lit_MagicMountain: 4 out of 8 answers
# INFO:root:Correct answers for Lit_Solaris: 2 out of 6 answers
# INFO:root:Correct answers for Lit_BrokenApril: 1 out of 6 answers
# INFO:root:Correct answers for Arg_PISACowsMilk: 3 out of 6 answers
# INFO:root:Correct answers for Arg_PISARapaNui: 4 out of 8 answers
# INFO:root:Correct answers for PopSci_Caveman: 4 out of 6 answers
# INFO:root:Overall correct answers: 29 out of 64 answers 0.45
# Checking PopSci_MultiplEYE in Logfile
# Checking Ins_HumanRights in Logfile
# Checking Ins_LearningMobility in Logfile
# Checking Lit_Alchemist in Logfile
# Checking Lit_MagicMountain in Logfile
# Checking Lit_Solaris in Logfile
# Checking Lit_BrokenApril in Logfile
# Checking Arg_PISACowsMilk in Logfile
# Checking Arg_PISARapaNui in Logfile
# Checking PopSci_Caveman in Logfile
# WARNING:root:Missing question_MPRC_Arg_PISARapaNui_ru_11121 in asc file
# WARNING:root:Missing question_MPRC_Arg_PISARapaNui_ru_11131 in asc file
# WARNING:root:Missing question_MPRC_Arg_PISARapaNui_ru_11232 in asc file
# 6, MSG	882687 stimulus_order_version: 6
# INFO:root:1:  Lit_MagicMountain: 6.62 minutes
# INFO:root:2:  Arg_PISARapaNui: 14.26 minutes
# INFO:root:3:  Lit_Solaris: 17.89 minutes
# INFO:root:4:  PopSci_Caveman: 10.21 minutes
# INFO:root:5: Arg_PISACowsMilk: 9.96 minutes
# INFO:root:obligatory break: 9.83 minutes
# INFO:root:6:  Lit_BrokenApril: 6.07 minutes
# INFO:root:7:  Ins_HumanRights: 5.05 minutes
# INFO:root:8:  PopSci_MultiplEYE: 17.7 minutes
# INFO:root:9:  Lit_Alchemist: 4.57 minutes
# INFO:root:10:  Ins_LearningMobility: 6.13 minutes
# INFO:root:fixation_trigger:experimenter_calibration_triggered found 6 times
# INFO:root:fixation_trigger:experimenter_calibration_triggered found at 1523867
# INFO:root:fixation_trigger:experimenter_calibration_triggered found at 1623088
# INFO:root:fixation_trigger:experimenter_calibration_triggered found at 2024426
# INFO:root:fixation_trigger:experimenter_calibration_triggered found at 2808499
# INFO:root:fixation_trigger:experimenter_calibration_triggered found at 2951100
# INFO:root:fixation_trigger:experimenter_calibration_triggered found at 5715498
# INFO:root:optional_break found 8 times
# INFO:root:optional_break_duration: lasting 7.02 seconds found at 1842642
# INFO:root:optional_break_duration: lasting 5.51 seconds found at 2676470
# INFO:root:optional_break_duration: lasting 9.60 seconds found at 3697767
# INFO:root:optional_break_duration: lasting 267.27 seconds found at 4388433
# INFO:root:optional_break_duration: lasting 8.83 seconds found at 5938761
# INFO:root:optional_break_duration: lasting 2.88 seconds found at 6244189
# INFO:root:optional_break_duration: lasting 489.66 seconds found at 7308205
# INFO:root:optional_break_duration: lasting 2.26 seconds found at 7576057
# INFO:root:obligatory_break found 1 times
# INFO:root:obligatory_break_duration: lasting 546.57 seconds found at 5564769
# 6, MSG	882687 stimulus_order_version: 6
# INFO:root:Calibration after validation at timestamp 1087844.   Next validation, 53.901 seconds later with score 0.41
# INFO:root:No calibration after validation 2/20 at 1102943.0 with validation score 0.41
# INFO:root:Calibration after validation at timestamp 1460523.   Next validation, 52.004 seconds later with score 0.35
# INFO:root:Calibration after validation at timestamp 1534491.   Next validation, 52.004 seconds later with score 0.35
# INFO:root:Calibration after validation at timestamp 1534491.   Next validation, 79.37 seconds later with score 0.45
# INFO:root:Calibration after validation at timestamp 1655956.   Next validation, 79.37 seconds later with score 0.45
# INFO:root:Calibration after validation at timestamp 1655956.   Next validation, 121.822 seconds later with score 0.29
# INFO:root:No calibration after validation 7/20 at 1873553.0 with validation score 0.35
# INFO:root:No calibration after validation 8/20 at 2464246.0 with validation score 0.40
# INFO:root:Calibration after validation at timestamp 2825493.   Next validation, 155.996 seconds later with score 0.25
# INFO:root:Calibration after validation at timestamp 2858628.   Next validation, 155.996 seconds later with score 0.25
# INFO:root:No calibration after validation 11/20 at 3362680.0 with validation score 0.34
# INFO:root:No calibration after validation 13/20 at 4415804.0 with validation score 0.33
# INFO:root:No calibration after validation 15/20 at 5742900.0 with validation score 0.38
# INFO:root:No calibration after validation 16/20 at 5967302.0 with validation score 0.34
# INFO:root:No calibration after validation 20/20 at 7976730.0 with validation score 0.33
# INFO:root: creating plots for 002_RU_RU_1_ET1.
# performing sanity checks: 100%|██████████| 1/1 [00:52<00:00, 52.65s/it]

# %%
from multipleye_data_collection import MultipleyeDataCollection
from experiment_frame import ExperimentFrame
from pathlib import Path
import logging
logging.basicConfig(level=logging.INFO)
data_collection_folder = 'MultiplEYE_CS_CZ_Prague_1_2025'
this_repo = Path().resolve().parent
data_folder_path = this_repo / "data" / data_collection_folder
print(data_folder_path)

multipleye = MultipleyeDataCollection.create_from_data_folder(str(data_folder_path), different_stimulus_names="split", additional_folder= 'pilot_sessions')
# Out:
# C:\Users\saphi\PycharmProjects\multipleye-preprocessing\data\MultiplEYE_CS_CZ_Prague_1_2025
# Folder quality_reports does not match the regex pattern \d\d\d_CS_CZ_1_ET\d. Not considered as session.
# Converting EDF to ASC: 100%|██████████| 7/7 [00:00<00:00, 447.37it/s]
# ASC file already exists for 001_CS_CZ_1_ET1.
# ASC file already exists for 001_CS_CZ_1_ET2.
# ASC file already exists for 002_CS_CZ_1_ET1.
# ASC file already exists for 002_CS_CZ_1_ET2.
# ASC file already exists for 003_CS_CZ_1_ET1.
# ASC file already exists for 003_CS_CZ_1_ET2.
# ASC file already exists for 999_CS_CZ_1_ET1.

# %%
multipleye.different_stimulus_names = "split"
multipleye.create_sanity_check_report(plotting= True)
# Out:
# performing sanity checks:   0%|          | 0/7 [00:00<?, ?it/s]
# C:\Users\saphi\PycharmProjects\multipleye-preprocessing\data\MultiplEYE_CS_CZ_Prague_1_2025\eye-tracking-sessions\quality_reports\001_CS_CZ_1_ET1\001_CS_CZ_1_ET1_gaze.pkl
# <class 'pathlib.WindowsPath'>
# <_io.BufferedReader name='C:\\Users\\saphi\\PycharmProjects\\multipleye-preprocessing\\data\\MultiplEYE_CS_CZ_Prague_1_2025\\eye-tracking-sessions\\quality_reports\\001_CS_CZ_1_ET1\\001_CS_CZ_1_ET1_gaze.pkl'>
# INFO:root:Correct answers for Arg_PISARapaNui: 2 out of 8 answers
# INFO:root:Correct answers for PopSci_Caveman: 3 out of 6 answers
# INFO:root:Correct answers for Lit_Solaris: 1 out of 6 answers
# INFO:root:Correct answers for Lit_MagicMountain: 3 out of 6 answers
# INFO:root:Correct answers for Arg_PISACowsMilk: 4 out of 6 answers
# INFO:root:Overall correct answers: 13 out of 32 answers 0.41
# Checking Arg_PISARapaNui in Logfile
# Checking PopSci_Caveman in Logfile
# Checking Lit_Solaris in Logfile
# Checking Lit_MagicMountain in Logfile
# Checking Arg_PISACowsMilk in Logfile
# 238, MSG	1399711 stimulus_order_version: 238
# INFO:root:'obligatory_break' is not in list only acceptable if MERid version
# INFO:root:1:  Arg_PISARapaNui: 6.79 minutes
# INFO:root:'obligatory_break' is not in list only acceptable if MERid version
# INFO:root:2:  PopSci_Caveman: 4.66 minutes
# INFO:root:'obligatory_break' is not in list only acceptable if MERid version
# INFO:root:3:  Lit_Solaris: 6.65 minutes
# INFO:root:'obligatory_break' is not in list only acceptable if MERid version
# INFO:root:4:  Lit_MagicMountain: 3.98 minutes
# INFO:root:'obligatory_break' is not in list only acceptable if MERid version
# INFO:root:5:  Arg_PISACowsMilk: 5.71 minutes
# WARNING:root:Missing one time screen start_recording_PRACTICE_trial_2_stimulus_Lit_NorthWind_7_page_1 in asc file
# WARNING:root:Missing one time screen stop_recording_PRACTICE_trial_2_stimulus_Lit_NorthWind_7_page_1 in asc file
# WARNING:root:Missing one time screen obligatory_break in asc file
# WARNING:root:Missing one time screen obligatory_break_end in asc file
# INFO:root:fixation_trigger:experimenter_calibration_triggered found 1 times
# INFO:root:fixation_trigger:experimenter_calibration_triggered found at 1533585
# INFO:root:optional_break found 4 times
# INFO:root:optional_break_duration: lasting 12.46 seconds found at 2282104
# INFO:root:optional_break_duration: lasting 6.10 seconds found at 2588779
# INFO:root:optional_break_duration: lasting 18.39 seconds found at 2983573
# INFO:root:optional_break_duration: lasting 11.14 seconds found at 3223849
# Missing screen start_recording_PRACTICE_trial_2_stimulus_Lit_NorthWind_7_page_1
# Missing screen stop_recording_PRACTICE_trial_2_stimulus_Lit_NorthWind_7_page_1
# Missing screen obligatory_break
# Missing screen obligatory_break_end
# 238, MSG	1399711 stimulus_order_version: 238
# INFO:root:Calibration after validation at timestamp 1705911.   Next validation, 55.838 seconds later with score 0.26
# INFO:root: creating plots for 001_CS_CZ_1_ET1.
# performing sanity checks:   0%|          | 0/7 [00:07<?, ?it/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 multipleye.different_stimulus_names = "split"
# ----> 2 multipleye.create_sanity_check_report(plotting= True)
#
# File ~\PycharmProjects\multipleye-preprocessing\quality-report\multipleye_data_collection.py:330, in MultipleyeDataCollection.create_sanity_check_report(self, sessions, plotting)
#     327 #self.get_stimulus_order_version_csv(session_name)
#     329 if plotting:
# --> 330     self.create_plots(session_name, gaze)
#
# File ~\PycharmProjects\multipleye-preprocessing\quality-report\multipleye_data_collection.py:360, in MultipleyeDataCollection.create_plots(self, session_identifier, gaze)
#     358 for stimulus in self.sessions[session_identifier]['session_stimuli']:
#     359     logging.debug(f"Creating plots for {stimulus.name}.")
# --> 360     plot_gaze(gaze, stimulus, plot_dir)
#
# File ~\PycharmProjects\multipleye-preprocessing\quality-report\et_quality_checks.py:178, in plot_gaze(gaze, stimulus, plots_dir)
#     167 page_events = gaze.events.frame.filter(
#     168     (pl.col("stimulus") == f"{stimulus.name}_{stimulus.id}")
#     169     & (pl.col("screen") == screen_name)
#    (...)    174     pl.col("location").list.get(1).alias("pixel_y"),
#     175 )
#     177 fig, ax = plt.subplots()
# --> 178 question_image = PIL.Image.open(question.image_path)
#     179 ax.imshow(question_image)
#     181 # Plot raw gaze data
#
# File ~\PycharmProjects\multipleye-preprocessing\venv\Lib\site-packages\PIL\Image.py:3431, in open(fp, mode, formats)
#    3428     filename = os.path.realpath(os.fspath(fp))
#    3430 if filename:
# -> 3431     fp = builtins.open(filename, "rb")
#    3432     exclusive_fp = True
#    3433 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\saphi\\PycharmProjects\\multipleye-preprocessing\\data\\MultiplEYE_CS_CZ_Prague_1_2025\\stimuli_MultiplEYE_CS_CZ_Prague_1_2025\\question_images_cs_cz_1\\question_images_version_238\\Enc_WikiMoon_id13_question_13121_CS.png'
