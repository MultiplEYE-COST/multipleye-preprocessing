# %%
from multipleye_data_collection import MultipleyeDataCollection
from pathlib import Path
import logging

# %% [markdown]
# ## Specify multipleye data collection folder

# %%
logging.basicConfig(level=logging.INFO)
data_collection_folder = 'MultiplEYE_EN_US_NewYork_1_2025'

# %%
this_repo = Path().resolve().parent
data_folder_path = this_repo / "data" / data_collection_folder 
print(data_folder_path)

multipleye = MultipleyeDataCollection.create_from_data_folder(str(data_folder_path), additional_folder= 'pilot_sessions')
# Out:
# C:\Users\saphi\PycharmProjects\multipleye-preprocessing\data\MultiplEYE_EN_US_NewYork_1_2025
# Converting EDF to ASC: 100%|██████████| 3/3 [00:00<?, ?it/s]
# ASC file already exists for 001_EN_US_1_ET1.
# ASC file already exists for 002_EN_US_1_ET1.
# ASC file already exists for 003_EN_US_1_ET1.

# %%
multipleye.create_gaze_frame("002_EN_US_1_ET1")
# Out:
# Creating gaze data:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
gaze_016 = multipleye.get_gaze_frame("002_EN_US_1_ET1")

# %%
multipleye.create_gaze_frame("003_EN_US_1_ET1")
# Out:
# Creating gaze data:   0%|          | 0/1 [00:00<?, ?it/s]WARNING:root:Preprocessing gaze data for 003_EN_US_1_ET1. This might take a while.
# Experiment(sampling_rate=1000.00, screen=Screen(width_px=1341, height_px=1009, width_cm=37, height_cm=28, distance_cm=60, origin=upper left), eyetracker=EyeTracker(sampling_rate=1000.0, left=True, right=False, model='EyeLink 1000 Plus', version='5.50', vendor='EyeLink', mount='Desktop'))
# Creating gaze data: 100%|██████████| 1/1 [06:36<00:00, 396.62s/it]

# %%
multipleye.create_sanity_check_report("016_ET_EE_1_ET1")
# Out:
# performing sanity checks:   0%|          | 0/1 [00:00<?, ?it/s]INFO:root:Correct answers for PopSci_MultiplEYE: 4 out of 6 answers
# INFO:root:Correct answers for Ins_HumanRights: 4 out of 6 answers
# INFO:root:Correct answers for Ins_LearningMobility: 5 out of 8 answers
# INFO:root:Correct answers for Lit_Alchemist: 6 out of 8 answers
# INFO:root:Correct answers for Lit_MagicMountain: 3 out of 6 answers
# INFO:root:Correct answers for Lit_Solaris: 1 out of 6 answers
# INFO:root:Correct answers for Lit_BrokenApril: 4 out of 6 answers
# INFO:root:Correct answers for Arg_PISACowsMilk: 3 out of 6 answers
# INFO:root:Correct answers for Arg_PISARapaNui: 3 out of 6 answers
# INFO:root:Correct answers for PopSci_Caveman: 4 out of 6 answers
# INFO:root:Overall correct answers: 37 out of 64 answers 0.58
# INFO:root:1:  Ins_LearningMobility: 13.11 minutes
# INFO:root:2:  Lit_Alchemist: 7.58 minutes
# INFO:root:3:  PopSci_MultiplEYE: 23.53 minutes
# INFO:root:4:  Ins_HumanRights: 8.28 minutes
# INFO:root:5: PopSci_Caveman: 7.08 minutes
# INFO:root:obligatory break: 15.32 minutes
# INFO:root:6:  Lit_Solaris: 11.14 minutes
# INFO:root:7:  Lit_BrokenApril: 9.8 minutes
# INFO:root:8:  Arg_PISACowsMilk: 10.46 minutes
# INFO:root:9:  Arg_PISARapaNui: 9.22 minutes
# INFO:root:10:  Lit_MagicMountain: 5.89 minutes
# INFO:root:optional_break found 8 times
# INFO:root:optional_break_duration: lasting 8.70 seconds found at 3066718
# INFO:root:optional_break_duration: lasting 16.32 seconds found at 3478140
# INFO:root:optional_break_duration: lasting 818.41 seconds found at 4965140
# INFO:root:optional_break_duration: lasting 1.84 seconds found at 5396529
# INFO:root:optional_break_duration: lasting 4.75 seconds found at 7430183
# INFO:root:optional_break_duration: lasting 4.16 seconds found at 7935860
# INFO:root:optional_break_duration: lasting 6.22 seconds found at 8595728
# INFO:root:optional_break_duration: lasting 35.30 seconds found at 9205165
# INFO:root:obligatory_break found 1 times
# INFO:root:obligatory_break_duration: lasting 776.06 seconds found at 6713707
# INFO:root:No calibration after validation 3/15 at 3136021.0 with validation score 0.32
# INFO:root:Calibration after validation at timestamp 3578532.   Next validation, 65.362 seconds later with score 0.21
# INFO:root: creating plots for 016_ET_EE_1_ET1.
# performing sanity checks: 100%|██████████| 1/1 [02:38<00:00, 158.30s/it]

# %%
multipleye.create_sanity_check_report(plotting= True)
# Out:
# performing sanity checks: 0it [00:00, ?it/s]INFO:root:Correct answers for PopSci_MultiplEYE: 3 out of 6 answers
# INFO:root:Correct answers for Ins_HumanRights: 3 out of 6 answers
# INFO:root:Correct answers for Ins_LearningMobility: 4 out of 6 answers
# INFO:root:Correct answers for Lit_Alchemist: 3 out of 6 answers
# INFO:root:Correct answers for Lit_MagicMountain: 2 out of 6 answers
# INFO:root:Correct answers for Lit_Solaris: 4 out of 8 answers
# INFO:root:Correct answers for Lit_BrokenApril: 1 out of 6 answers
# INFO:root:Correct answers for Arg_PISACowsMilk: 3 out of 6 answers
# INFO:root:Correct answers for Arg_PISARapaNui: 5 out of 6 answers
# INFO:root:Correct answers for PopSci_Caveman: 4 out of 8 answers
# INFO:root:Overall correct answers: 32 out of 64 answers 0.50
# INFO:root:1:  PopSci_Caveman: 7.36 minutes
# INFO:root:2:  Lit_Solaris: 9.98 minutes
# INFO:root:3:  Lit_BrokenApril: 5.62 minutes
# INFO:root:4:  Arg_PISACowsMilk: 5.29 minutes
# INFO:root:5: Ins_LearningMobility: 2.77 minutes
# INFO:root:obligatory break: 5.83 minutes
# INFO:root:6:  Lit_Alchemist: 2.48 minutes
# INFO:root:7:  Arg_PISARapaNui: 3.79 minutes
# INFO:root:8:  Lit_MagicMountain: 2.88 minutes
# INFO:root:9:  PopSci_MultiplEYE: 4.35 minutes
# INFO:root:10:  Ins_HumanRights: 2.70 minutes
# INFO:root:fixation_trigger:skipped_by_experimenter found 1 times
# INFO:root:fixation_trigger:skipped_by_experimenter found at 4439992
# INFO:root:optional_break found 8 times
# INFO:root:optional_break_duration: lasting 31.38 seconds found at 4360045
# INFO:root:optional_break_duration: lasting 5.55 seconds found at 4781713
# INFO:root:optional_break_duration: lasting 2.38 seconds found at 5243479
# INFO:root:optional_break_duration: lasting 5.05 seconds found at 5575850
# INFO:root:optional_break_duration: lasting 1.73 seconds found at 6292369
# INFO:root:optional_break_duration: lasting 1.80 seconds found at 6518307
# INFO:root:optional_break_duration: lasting 1.64 seconds found at 6687077
# INFO:root:optional_break_duration: lasting 1.34 seconds found at 6939417
# INFO:root:obligatory_break found 1 times
# INFO:root:obligatory_break_duration: lasting 302.57 seconds found at 6125281
# INFO:root:Calibration after validation at timestamp 1428755.   Next validation, 125.607 seconds later with score 1.24
# INFO:root:Calibration after validation at timestamp 1601482.   Next validation, 174.839 seconds later with score 0.97
# INFO:root:No calibration after validation 3/22 at 1653771.0 with validation score 0.97
# INFO:root:No calibration after validation 4/22 at 2929603.0 with validation score 0.50
# INFO:root:No calibration after validation 5/22 at 3016071.0 with validation score 0.47
# INFO:root:Calibration after validation at timestamp 3388350.   Next validation, 134.985 seconds later with score 0.47
# INFO:root:No calibration after validation 7/22 at 3414981.0 with validation score 0.47
# INFO:root:Calibration after validation at timestamp 3896683.   Next validation, 59.351 seconds later with score 0.37
# INFO:root:No calibration after validation 9/22 at 3921407.0 with validation score 0.37
# INFO:root:Calibration after validation at timestamp 4882877.   Next validation, 33.311 seconds later with score 0.96
# INFO:root:Calibration after validation at timestamp 4882877.   Next validation, 55.685 seconds later with score 0.67
# INFO:root:No calibration after validation 12/22 at 4906304.0 with validation score 0.67
# INFO:root:No calibration after validation 13/22 at 4967153.0 with validation score 0.57
# INFO:root:Calibration after validation at timestamp 5300213.   Next validation, 46.23 seconds later with score 0.35
# INFO:root:No calibration after validation 15/22 at 5315476.0 with validation score 0.35
# INFO:root:Calibration after validation at timestamp 5629894.   Next validation, 47.8 seconds later with score 0.36
# INFO:root:No calibration after validation 17/22 at 5645396.0 with validation score 0.36
# INFO:root:No calibration after validation 19/22 at 6307494.0 with validation score 0.54
# INFO:root:No calibration after validation 20/22 at 6535588.0 with validation score 0.69
# INFO:root:No calibration after validation 21/22 at 6707729.0 with validation score 0.64
# INFO:root:No calibration after validation 22/22 at 6956397.0 with validation score 0.46
# INFO:root: creating plots for 001_EN_US_1_ET1.
# performing sanity checks: 1it [00:40, 40.46s/it]INFO:root:Correct answers for PopSci_MultiplEYE: 7 out of 8 answers
# INFO:root:Correct answers for Ins_HumanRights: 6 out of 8 answers
# INFO:root:Correct answers for Ins_LearningMobility: 5 out of 6 answers
# INFO:root:Correct answers for Lit_Alchemist: 4 out of 6 answers
# INFO:root:Correct answers for Lit_MagicMountain: 3 out of 6 answers
# INFO:root:Correct answers for Lit_Solaris: 1 out of 6 answers
# INFO:root:Correct answers for Lit_BrokenApril: 4 out of 6 answers
# INFO:root:Correct answers for Arg_PISACowsMilk: 3 out of 6 answers
# INFO:root:Correct answers for Arg_PISARapaNui: 4 out of 6 answers
# INFO:root:Correct answers for PopSci_Caveman: 5 out of 6 answers
# INFO:root:Overall correct answers: 42 out of 64 answers 0.66
# INFO:root:1:  Ins_HumanRights: 5.66 minutes
# INFO:root:2:  PopSci_MultiplEYE: 6.59 minutes
# INFO:root:3:  Lit_Alchemist: 3.88 minutes
# INFO:root:4:  Ins_LearningMobility: 6.04 minutes
# INFO:root:5: Lit_MagicMountain: 5.06 minutes
# INFO:root:obligatory break: 6.71 minutes
# INFO:root:6:  Arg_PISARapaNui: 6.4 minutes
# INFO:root:7:  Lit_Solaris: 7.88 minutes
# INFO:root:8:  PopSci_Caveman: 4.93 minutes
# INFO:root:9:  Arg_PISACowsMilk: 6.15 minutes
# INFO:root:10:  Lit_BrokenApril: 5.50 minutes
# INFO:root:optional_break found 8 times
# INFO:root:optional_break_duration: lasting 3.07 seconds found at 3308909
# INFO:root:optional_break_duration: lasting 14.96 seconds found at 3733186
# INFO:root:optional_break_duration: lasting 2.25 seconds found at 3948661
# INFO:root:optional_break_duration: lasting 1.98 seconds found at 4312790
# INFO:root:optional_break_duration: lasting 2.11 seconds found at 5372755
# INFO:root:optional_break_duration: lasting 1.76 seconds found at 5892008
# INFO:root:optional_break_duration: lasting 1.60 seconds found at 6186843
# INFO:root:optional_break_duration: lasting 1.72 seconds found at 6557695
# INFO:root:obligatory_break found 1 times
# INFO:root:obligatory_break_duration: lasting 325.83 seconds found at 4982000
# INFO:root:Calibration after validation at timestamp 5417827.   Next validation, 44.507 seconds later with score 0.23
# INFO:root: creating plots for 002_EN_US_1_ET1.
# performing sanity checks: 2it [01:32, 47.33s/it]INFO:root:Correct answers for PopSci_MultiplEYE: 6 out of 6 answers
# INFO:root:Correct answers for Ins_HumanRights: 4 out of 6 answers
# INFO:root:Correct answers for Ins_LearningMobility: 7 out of 8 answers
# INFO:root:Correct answers for Lit_Alchemist: 5 out of 8 answers
# INFO:root:Correct answers for Lit_MagicMountain: 4 out of 6 answers
# INFO:root:Correct answers for Lit_Solaris: 4 out of 6 answers
# INFO:root:Correct answers for Lit_BrokenApril: 6 out of 6 answers
# INFO:root:Correct answers for Arg_PISACowsMilk: 4 out of 6 answers
# INFO:root:Correct answers for Arg_PISARapaNui: 6 out of 6 answers
# INFO:root:Correct answers for PopSci_Caveman: 5 out of 6 answers
# INFO:root:Overall correct answers: 51 out of 64 answers 0.80
# INFO:root:1:  Lit_Alchemist: 3.15 minutes
# INFO:root:2:  Ins_LearningMobility: 5.41 minutes
# INFO:root:3:  Ins_HumanRights: 3.88 minutes
# INFO:root:4:  PopSci_MultiplEYE: 6.21 minutes
# INFO:root:5: Lit_Solaris: 6.34 minutes
# INFO:root:obligatory break: 8.47 minutes
# INFO:root:6:  PopSci_Caveman: 3.44 minutes
# INFO:root:7:  Arg_PISACowsMilk: 5.17 minutes
# INFO:root:8:  Lit_BrokenApril: 4.62 minutes
# INFO:root:9:  Lit_MagicMountain: 4.48 minutes
# INFO:root:10:  Arg_PISARapaNui: 4.11 minutes
# INFO:root:fixation_trigger:experimenter_calibration_triggered found 2 times
# INFO:root:fixation_trigger:experimenter_calibration_triggered found at 2425771
# INFO:root:fixation_trigger:experimenter_calibration_triggered found at 5463649
# INFO:root:optional_break found 8 times
# INFO:root:optional_break_duration: lasting 4.56 seconds found at 2597004
# INFO:root:optional_break_duration: lasting 78.11 seconds found at 2904271
# INFO:root:optional_break_duration: lasting 2.54 seconds found at 3152258
# INFO:root:optional_break_duration: lasting 2.49 seconds found at 3526774
# INFO:root:optional_break_duration: lasting 2.41 seconds found at 4620786
# INFO:root:optional_break_duration: lasting 2.11 seconds found at 4927621
# INFO:root:optional_break_duration: lasting 1.79 seconds found at 5210649
# INFO:root:optional_break_duration: lasting 13.32 seconds found at 5459627
# INFO:root:obligatory_break found 1 times
# INFO:root:obligatory_break_duration: lasting 461.19 seconds found at 4393567
# INFO:root:Calibration after validation at timestamp 2399908.   Next validation, 50.579 seconds later with score 0.20
# INFO:root:No calibration after validation 10/13 at 4947634.0 with validation score 0.31
# INFO:root: creating plots for 003_EN_US_1_ET1.
# performing sanity checks: 3it [02:18, 46.23s/it]

# %%
multipleye.create_gaze_frame("020_ET_EE_1_ET1")
# Out:
# Creating gaze data:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
multipleye.create_sanity_check_report("002_RU_RU_1_ET1", plotting= True)
# Out:
# performing sanity checks:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating gaze data:   0%|          | 0/1 [00:00<?, ?it/s]WARNING:root:Preprocessing gaze data for 001_RU_RU_1_ET1. This might take a while.
# Experiment(sampling_rate=1000.00, screen=Screen(width_px=1338, height_px=1015, width_cm=37, height_cm=28, distance_cm=60, origin=upper left), eyetracker=EyeTracker(sampling_rate=1000.0, left=False, right=True, model='EyeLink 1000 Plus', version='5.03', vendor='EyeLink', mount='Desktop'))
# Creating gaze data: 100%|██████████| 1/1 [06:02<00:00, 362.82s/it]
# INFO:root:Correct answers for PopSci_MultiplEYE: 0 out of 6 answers
# INFO:root:Correct answers for Ins_HumanRights: 1 out of 6 answers
# INFO:root:Correct answers for Ins_LearningMobility: 4 out of 6 answers
# INFO:root:Correct answers for Lit_Alchemist: 5 out of 6 answers
# INFO:root:Correct answers for Lit_MagicMountain: 3 out of 6 answers
# INFO:root:Correct answers for Lit_Solaris: 1 out of 6 answers
# INFO:root:Correct answers for Lit_BrokenApril: 4 out of 8 answers
# INFO:root:Correct answers for Arg_PISACowsMilk: 3 out of 8 answers
# INFO:root:Correct answers for Arg_PISARapaNui: 3 out of 6 answers
# INFO:root:Correct answers for PopSci_Caveman: 2 out of 6 answers
# INFO:root:Overall correct answers: 26 out of 64 answers 0.41
# INFO:root:1:  Arg_PISACowsMilk: 6.24 minutes
# INFO:root:2:  Lit_BrokenApril: 5.83 minutes
# INFO:root:3:  Lit_MagicMountain: 5.62 minutes
# INFO:root:4:  Arg_PISARapaNui: 5.6 minutes
# INFO:root:5: Ins_HumanRights: 4.59 minutes
# INFO:root:obligatory break: 0.64 minutes
# INFO:root:6:  PopSci_MultiplEYE: 6.05 minutes
# INFO:root:7:  Lit_Alchemist: 2.74 minutes
# INFO:root:8:  Ins_LearningMobility: 4.13 minutes
# INFO:root:9:  Lit_Solaris: 5.61 minutes
# INFO:root:10:  PopSci_Caveman: 3.14 minutes
# INFO:root:fixation_trigger:experimenter_calibration_triggered found 1 times
# INFO:root:fixation_trigger:experimenter_calibration_triggered found at 2109263.0
# INFO:root:optional_break found 8 times
# INFO:root:optional_break_duration: lasting 0.46 seconds found at 1625706.0
# INFO:root:optional_break_duration: lasting 5.74 seconds found at 1885501.0
# INFO:root:optional_break_duration: lasting 1.63 seconds found at 2291148.0
# INFO:root:optional_break_duration: lasting 5.29 seconds found at 2623858.0
# INFO:root:optional_break_duration: lasting 0.59 seconds found at 3365980.0
# INFO:root:optional_break_duration: lasting 0.85 seconds found at 3528092.0
# INFO:root:optional_break_duration: lasting 1.34 seconds found at 3762990.0
# INFO:root:optional_break_duration: lasting 1.18 seconds found at 4074152.0
# INFO:root:obligatory_break found 1 times
# INFO:root:obligatory_break_duration: lasting 1.43 seconds found at 2994743.0
# INFO:root:No calibration after validation 2/13 at 1687075.0 with validation score 0.45
# INFO:root:Calibration after validation at timestamp 2127035.0.   Next validation, 101.521 seconds later with score 0.31
# INFO:root:Calibration after validation at timestamp 2310670.0.   Next validation, 234.759 seconds later with score 0.26
# INFO:root:Calibration after validation at timestamp 2341544.0.   Next validation, 234.759 seconds later with score 0.26
# INFO:root:Calibration after validation at timestamp 2692287.0.   Next validation, 45.302 seconds later with score 0.41
# INFO:root:No calibration after validation 7/13 at 2713228.0 with validation score 0.41
# INFO:root:No calibration after validation 8/13 at 3027384.0 with validation score 0.37
# INFO:root:No calibration after validation 11/13 at 3802006.0 with validation score 0.49
# INFO:root:No calibration after validation 13/13 at 4330336.0 with validation score 0.40
# INFO:root: creating plots for 001_RU_RU_1_ET1.
# performing sanity checks: 100%|██████████| 1/1 [07:52<00:00, 472.36s/it]
